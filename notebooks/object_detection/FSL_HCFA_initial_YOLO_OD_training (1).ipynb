# %%
import os
train_img = []

for img in os.listdir("/content/drive/MyDrive/001_projects/FSL/data/Phase-II/HCFA/images/train"):
  train_img.append(img[:-5])

# %%
import shutil

for txt_name in train_img:
  print(txt_name)
  shutil.copy(f"/content/drive/MyDrive/001_projects/FSL/data/Phase-II/HCFA/{txt_name}.txt", "/content/drive/MyDrive/001_projects/FSL/data/Phase-II/HCFA/labels/train")

# %%
import os
valid_img = []

for img in os.listdir("/content/drive/MyDrive/001_projects/FSL/data/Phase-II/HCFA/images/valid"):
  valid_img.append(img[:-5])

# %%
import shutil

for txt_name in valid_img:
  print(txt_name)
  shutil.copy(f"/content/drive/MyDrive/001_projects/FSL/data/Phase-II/HCFA/{txt_name}.txt", "/content/drive/MyDrive/001_projects/FSL/data/Phase-II/HCFA/labels/valid")

# %%
import yaml
from glob import glob
with open('/content/drive/MyDrive/001_projects/FSL/data/Phase-II/HCFA/train.txt', 'w') as f:
    for path in glob('/content/drive/MyDrive/001_projects/FSL/data/Phase-II/HCFA/images/train/*'):
        f.write(path+'\n')

with open('/content/drive/MyDrive/001_projects/FSL/data/Phase-II/HCFA/val.txt', 'w') as f:
    for path in glob('/content/drive/MyDrive/001_projects/FSL/data/Phase-II/HCFA/images/valid/*'):
        f.write(path+'\n')

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.2/645.2 kB 8.4 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %%
model = YOLO(model="yolov8n.yaml")
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
import os
os.environ['WANDB_DISABLED'] = 'true'

# %%
results = model.train(data='/content/drive/MyDrive/001_projects/FSL/data/Phase-II/HCFA/data.yaml', epochs=100, imgsz=1440, batch=8, project='/content/drive/MyDrive/001_projects/FSL/yolo_initial_model_v2')
# Out:
# Ultralytics YOLOv8.0.207 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# ...

# %%
import torch
torch.cuda.is_available()
# Out:
# True
