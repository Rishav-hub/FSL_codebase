# %% [markdown]
# ### Connect to Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # YOLO Format

# %% [markdown]
# ### Load data

# %%
# !unzip "/content/drive/MyDrive/001_projects/FSL/data/annotation_data/HCFA/pseudo_label_hcfa_500.zip"

# %%
# !unzip "/content/project-4-at-2023-12-13-17-50-fd88f887_HCFA_500_YOLO.zip"

# %%
import os

os.listdir("/content/content/psudo_lable_hcfa_500/images").__len__()

# %%
# !cp -r "/content/content/psudo_lable_hcfa_500/images" "/content/hcfa_augmented_human_annotated_500"

# %% [markdown]
# #### ADA

# %%
# !unzip /content/drive/MyDrive/001_projects/FSL/FSL_annotations/CIGNA_DENTAL_ADA/Cigna_Dental.zip

# %%
# !unzip /content/drive/MyDrive/001_projects/FSL/FSL_annotations/CIGNA_DENTAL_ADA/batch_1/project-8-at-2024-01-05-17-49-50518453_CIGNA_ADA_51_YOLO.zip

# %%
# !unzip /content/drive/MyDrive/001_projects/FSL/FSL_annotations/CIGNA_DENTAL_ADA/batch_1/project-8-at-2024-01-05-17-50-50518453_CIGNA_ADA_51_COCO.zip
# Out:
# Archive:  /content/drive/MyDrive/001_projects/FSL/FSL_annotations/CIGNA_DENTAL_ADA/batch_1/project-8-at-2024-01-05-17-50-50518453_CIGNA_ADA_51_COCO.zip
#   inflating: result.json

# %% [markdown]
# ### Check if the all the labels are available in Images

# %%
import os

# Set the paths for images and labels folders
images_folder = "/content/content/psudo_lable_hcfa_500/images"
# labels_folder = "/content/content/psudo_lable_hcfa_500/labels"
labels_folder = "/content/labels"


# Get a list of image file names without extensions
image_names = {os.path.splitext(file)[0] for file in os.listdir(images_folder) if os.path.isfile(os.path.join(images_folder, file))}

# Get a list of label file names without extensions
label_names = {os.path.splitext(file)[0] for file in os.listdir(labels_folder) if os.path.isfile(os.path.join(labels_folder, file))}

# Find labels without corresponding images
labels_without_images = label_names - image_names

if labels_without_images:
    print("Labels without corresponding images:")
    for label_name in labels_without_images:
        print(label_name)
else:
    print("All labels have corresponding images.")
# Out:
# All labels have corresponding images.

# %% [markdown]
# ### Rename all the files in a folder

# %%
import os

def rename_files(folder_path, prefix, extension=".txt"):
    # Get a list of files in the folder
    files = [f for f in os.listdir(folder_path) if f.endswith(extension)]

    # Iterate through the files and rename them
    for i, filename in enumerate(files, start=1):
      try:
        old_path = os.path.join(folder_path, filename)
        new_filename = filename.split("-")[1]
        new_path = os.path.join(folder_path, new_filename)

        # Rename the file
        os.rename(old_path, new_path)
        print(f"Renamed {filename} to {new_filename}")
      except Exception as e:
        print(e)
        # break
# Example usage
folder_path = '/content/labels'
prefix = 'new_prefix'

rename_files(folder_path, prefix)

# %% [markdown]
# ### Move images to a folder for which labels are available

# %%
import os
import shutil

def move_images(source_folder, destination_folder):
    # Ensure the destination folder exists
    os.makedirs(destination_folder, exist_ok=True)

    # Iterate through files in the source folder
    for filename in os.listdir(source_folder):
        if filename.endswith('.jpg'):
            image_path = os.path.join(source_folder, filename)
            txt_path = os.path.join("/content/labels", os.path.splitext(filename)[0] + '.txt')
            print(txt_path)
            # Check if the corresponding .txt file exists
            if os.path.exists(txt_path):
                # Move the image to the destination folder
                shutil.move(image_path, os.path.join(destination_folder, filename))
                print(f"Moved {filename} to {destination_folder}")
            else:
                print(f"No .txt file found for {filename}")

# Example usage
source_folder = '/content/Cigna_Dental'
destination_folder = '/content/images'

move_images(source_folder, destination_folder)

# %%
len(os.listdir("/content/images"))
# Out:
# 51

# %%
import os
import shutil
from sklearn.model_selection import train_test_split

# Define paths
root_folder = "/content/hcfa_augmented_human_annotated_500"
images_folder = os.path.join(root_folder, "images")
labels_folder = os.path.join(root_folder, "labels")

# Create train and val folders
root_train_folder = os.path.join("data", "images", "train")
root_val_folder = os.path.join("data", "images", "valid")
root_train_labels_folder = os.path.join("data", "labels", "train")
root_val_labels_folder = os.path.join("data", "labels", "valid")

os.makedirs(root_train_folder, exist_ok=True)
os.makedirs(root_val_folder, exist_ok=True)
os.makedirs(root_train_labels_folder, exist_ok=True)
os.makedirs(root_val_labels_folder, exist_ok=True)

# Get list of image files
image_files = [f for f in os.listdir(images_folder) if os.path.isfile(os.path.join(images_folder, f))]

# Split the dataset
train_images, val_images = train_test_split(image_files, test_size=0.01, random_state=42)

# Copy images to train folder
for image in train_images:
    shutil.copy(os.path.join(images_folder, image), os.path.join(root_train_folder, image))

# Copy labels to train folder
for image in train_images:
    label_file = os.path.splitext(image)[0] + ".txt"
    shutil.copy(os.path.join(labels_folder, label_file), os.path.join(root_train_labels_folder, label_file))

# Copy images to val folder
for image in val_images:
    shutil.copy(os.path.join(images_folder, image), os.path.join(root_val_folder, image))

# Copy labels to val folder
for image in val_images:
    label_file = os.path.splitext(image)[0] + ".txt"
    shutil.copy(os.path.join(labels_folder, label_file), os.path.join(root_val_labels_folder, label_file))

# %%
# !rm -rf "/content/data"

# %%
import os
os.listdir("/content/data/images/valid").__len__()
# Out:
# 4

# %% [markdown]
# ### Plot the existing annotations on Image
#
# Sanity check on the annotated images

# %%
import cv2
import os

# Define paths
images_folder = "/content/images"
labels_folder = "/content/labels"

# os.makedirs(images_folder, exist_ok= True)
# os.makedirs(labels_folder, exist_ok= True)

# Iterate through each image and its corresponding label
for idx, image_name in enumerate(os.listdir(images_folder)):

    if idx == 5:
      break

    if image_name.endswith(".jpg") or image_name.endswith(".png"):
        # Load the image
        image_path = os.path.join(images_folder, image_name)
        image = cv2.imread(image_path)

        # Load corresponding label file
        label_name = os.path.splitext(image_name)[0] + ".txt"
        label_path = os.path.join(labels_folder, label_name)

        # Read YOLO annotations from the label file
        with open(label_path, "r") as file:
            lines = file.readlines()

        # Parse YOLO annotations (assuming normalized coordinates)
        boxes = []
        for line in lines:
            class_id, x_center, y_center, width, height = map(float, line.strip().split())
            x, y, w, h = (
                int((x_center - width / 2) * image.shape[1]),
                int((y_center - height / 2) * image.shape[0]),
                int(width * image.shape[1]),
                int(height * image.shape[0]),
            )
            boxes.append((x, y, x + w, y + h))

        # Draw bounding boxes on the image
        for box in boxes:
            cv2.rectangle(image, (box[0], box[1]), (box[2], box[3]), (0, 255, 0), 2)

        # Display or save the result
        from google.colab.patches import cv2_imshow
        cv2_imshow(image)

# %%
# !rm -rf "/content/augmented_data"

# %%
import os
import cv2
import numpy as np
from albumentations import (
    Compose, HorizontalFlip, VerticalFlip, Rotate, RandomBrightnessContrast,
    RandomGamma, RandomResizedCrop, MotionBlur, ElasticTransform, GaussNoise, Blur,
    ColorJitter
)

def yolo_to_albumentations(yolo_box, image):
    # Convert YOLO format [center_x, center_y, width, height] to [x_min, y_min, x_max, y_max]

    image_width, image_height = image.shape[1], image.shape[0]  # Fix the width and height order
    center_x, center_y, width, height = yolo_box
    x_min = max(0, (center_x - width / 2))
    y_min = max(0, (center_y - height / 2))
    x_max = min(1, (center_x + width / 2))
    y_max = min(1, (center_y + height / 2))

    return [x_min, y_min, x_max, y_max]

def load_image_and_labels(image_path, label_path):
    # Load image
    image = cv2.imread(image_path)

    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Load labels (assuming YOLO format)
    labels = np.loadtxt(label_path).reshape(-1, 5)

    return image, labels

# def save_image_and_labels(image, labels, output_image_folder, output_labels_folder, filename, index):
#     # Save the image
#     cv2.imwrite(os.path.join(output_image_folder, f"{filename}_{index}.jpg"), cv2.cvtColor(image, cv2.COLOR_RGB2BGR))

#     # Save the augmented labels (assuming YOLO format)
#     np.savetxt(os.path.join(output_labels_folder, f"{filename}_{index}.txt"), labels, fmt='%.6f')

# def augment_and_save(image, labels, output_image_folder, output_labels_folder, filename, num_augmentations=10):
#     # Define augmentations
#     augmentations = Compose([
#         RandomBrightnessContrast(p=0.6),
#         RandomGamma(p=0.5),
#         Blur(blur_limit = 3, p=0.7),
#         ColorJitter(p=0.5)
#     ], bbox_params={'format': 'yolo', 'label_fields': ['category_id']})
#     # Apply augmentations and save the augmented images and labels
#     for i in range(num_augmentations):
#         # augmented = augmentations(image=image, bboxes=[yolo_to_albumentations(box, image) for box in labels[:, :4]], category_id=labels[:, 4])
#         augmented = augmentations(image=image, bboxes=labels[:, 1:5], category_id=labels[:, 0])
#         augmented_image = augmented['image']
#         # print(augmented_category_id)
#         augmented_labels = np.column_stack((augmented['category_id'].astype(int), augmented['bboxes']))
#         print("augmented_labels", augmented_labels)
#         save_image_and_labels(augmented_image, augmented_labels, output_image_folder, output_labels_folder, filename, i)

#     return augmented


def save_image_and_labels(image, labels, output_image_folder, output_labels_folder, filename, index):
    # Save the image
    cv2.imwrite(os.path.join(output_image_folder, f"{filename}_{index}.jpg"), cv2.cvtColor(image, cv2.COLOR_RGB2BGR))

    # Save the augmented labels (assuming YOLO format)
    np.savetxt(
        os.path.join(output_labels_folder, f"{filename}_{index}.txt"),
        labels, fmt=['%d', '%.6f', '%.6f', '%.6f', '%.6f']
    )

def augment_and_save(image, labels, output_image_folder, output_labels_folder, filename, num_augmentations=10):
    # Define augmentations
    augmentations = Compose([
        RandomBrightnessContrast(p=0.6),
        RandomGamma(p=0.5),
        Blur(blur_limit=3, p=0.7),
        ColorJitter(p=0.5)
    ], bbox_params={'format': 'yolo', 'label_fields': ['category_id']})

    # Apply augmentations and save the augmented images and labels
    for i in range(num_augmentations):
        augmented = augmentations(image=image, bboxes=labels[:, 1:5], category_id=labels[:, 0])

        # Convert category_id values to integers
        int_category_id = [int(x) for x in augmented['category_id']]

        # Stack the labels with the first column as integer and rest as floats
        augmented_labels = np.column_stack((int_category_id, augmented['bboxes']))

        save_image_and_labels(augmented['image'], augmented_labels, output_image_folder, output_labels_folder, filename, i)

    return augmented


# Input and Output folders
input_image_folder = "/content/images"
input_label_folder = "/content/labels"
output_image_folder = "/content/ada_batch_1_augmented_yolov8/images"
output_labels_folder = "/content/ada_batch_1_augmented_yolov8/labels"


# Create output folder if it doesn't exist
os.makedirs(output_image_folder, exist_ok=True)
os.makedirs(output_labels_folder, exist_ok=True)


# Process each image and labels
for filename in os.listdir(input_image_folder):
    if filename.endswith(".jpg"):  # Assuming images are in jpg format
        image_path = os.path.join(input_image_folder, filename)
        label_path = os.path.join(input_label_folder, f"{os.path.splitext(filename)[0]}.txt")

        image, labels = load_image_and_labels(image_path, label_path)

        augmented = augment_and_save(image, labels, output_image_folder, output_labels_folder, os.path.splitext(filename)[0], num_augmentations=5)

# %%
import gc
gc.collect()
# Out:
# 120

# %%
len(os.listdir("/content/hcfa_augmented_human_annotated_500_v1/images/valid"))
# Out:
# 20

# %%
# !zip -r "ada_batch_1_augmented_yolov8.zip" "./ada_batch_1_augmented_yolov8"

# %%
# !mv "/content/ada_batch_1_augmented_yolov8.zip" "/content/drive/MyDrive/001_projects/FSL/FSL_annotations/CIGNA_DENTAL_ADA/batch_1"

# %%
# !rm -rf "/content/drive/MyDrive/001_projects/FSL/data/augmented_data/augmented_updated_190.zip"

# %%
os.listdir("/content/data/images/train")

# %%
# !cp -r "/content/hcfa_augmented_human_annotated_500_v1/images" "/content/HCFA_coco_human_annotated_augmented_500/dataset"

# %% [markdown]
# ## Convert YOLO to COCO format
# code taken from other notebook

# %%
notes_json_path = "/content/hcfa_augmented_human_annotated_500_v1/notes.json"

# %%
import json

# Open and read the JSON file
with open(notes_json_path, 'r') as json_file:
    json_data = json.load(json_file)

# %%
categories = json_data['categories']

# %%
categories

# %%
import json
import os
from PIL import Image

# Set the paths for the input and output directories
input_dir = '/content/hcfa_augmented_human_annotated_500_v1/images/valid'
input_label_dir = "/content/hcfa_augmented_human_annotated_500_v1/labels/valid"
output_dir = '/content/coco/dataset'

os.makedirs(output_dir, exist_ok = True)

# %%
# # Define the categories for the COCO dataset
# categories = [{"id": 0, "name": "bottle"}]

# Define the COCO dataset dictionary
coco_dataset = {
    "info": {},
    "licenses": [],
    "categories": categories,
    "images": [],
    "annotations": []
}

# Loop through the images in the input directory
for image_id, image_file in enumerate(os.listdir(input_dir)):

    # Load the image and get its dimensions
    image_path = os.path.join(input_dir, image_file)
    image = Image.open(image_path)
    width, height = image.size

    # Add the image to the COCO dataset
    image_dict = {
        "id": image_id,
        "width": width,
        "height": height,
        "file_name": image_file
    }
    coco_dataset["images"].append(image_dict)

    # Load the bounding box annotations for the image
    with open(os.path.join(input_label_dir, f'{image_file.split(".")[0]}.txt')) as f:
        annotations = f.readlines()

    # Loop through the annotations and add them to the COCO dataset
    for annotation_id, ann in enumerate(annotations):
        x, y, w, h = map(float, ann.strip().split()[1:])
        x_min, y_min = int((x - w / 2) * width), int((y - h / 2) * height)
        x_max, y_max = int((x + w / 2) * width), int((y + h / 2) * height)
        ann_dict = {
            "id": annotation_id,
            "image_id": image_id,
            "category_id": class_id,
            "bbox": [x_min, y_min, x_max - x_min, y_max - y_min],
            "area": (x_max - x_min) * (y_max - y_min),
            "iscrowd": 0
        }
        coco_dataset["annotations"].append(ann_dict)
    # break

# Save the COCO dataset to a JSON file
with open(os.path.join(output_dir, 'valid.json'), 'w') as f:
    json.dump(coco_dataset, f)

# %%
# !unzip "/content/drive/MyDrive/001_projects/FSL/data/human_annotated/HCFA/HCFA_coco_human_annotated_augmented_500.zip"

# %%
import os
import json
from PIL import Image

def yolo_to_coco(yolo_images_folder, yolo_labels_folder, coco_annotations_path, notes_json_path= "/content/notes.json"):
    yolo_label_files = [f for f in os.listdir(yolo_labels_folder) if f.endswith(".txt")]

    with open(notes_json_path, 'r') as json_file:
      json_data = json.load(json_file)

    categories = json_data['categories']

    coco_data = {
        "images": [],
        "annotations": [],
        "categories": categories,
    }

    categories_dict = {}
    annotations = []

    for idx, label_file in enumerate(yolo_label_files):
        # image_id = str(label_file.split('.')[0])
        image_name = str(label_file.split('.')[0])
        image_path = os.path.join(yolo_images_folder, f"{image_name}.jpg")
        label_file_path = os.path.join(yolo_labels_folder, label_file)

        image = Image.open(image_path)
        width, height = image.size
        # COCO image entry
        image_entry = {
            "id": idx,
            "width": width,
            "height": height,
            "file_name": f"""images\\{image_name}.jpg""",
        }
        coco_data["images"].append(image_entry)

        with open(label_file_path, 'r') as yolo_file:
            lines = yolo_file.readlines()

        for line in lines:
            values = line.strip().split()
            class_id = int(values[0])
            bbox = [float(x) for x in values[1:5]]  # x_center, y_center, width, height

            # COCO annotation entry
            annotation_id = len(annotations) + 1
            annotation_entry = {
                "id": annotation_id,
                "image_id": idx,
                "category_id": class_id,
                "bbox": bbox,
                "area": bbox[2] * bbox[3],
                "iscrowd": 0,
            }
            annotations.append(annotation_entry)

            # COCO category entry
            # if class_id not in categories_dict:
            #     categories_dict[class_id] = True
            #     category_entry = {
            #         "id": class_id,
            #         "name": f"class_{class_id}",
            #         "supercategory": "object",
            #     }
            #     coco_data["categories"].append(category_entry)

    coco_data["annotations"] = annotations

    with open(coco_annotations_path, 'w') as coco_file:
        json.dump(coco_data, coco_file, indent=4)

# Example usage
yolo_to_coco('/content/ada_batch_1_augmented_yolov8/images', '/content/ada_batch_1_augmented_yolov8/labels', '/content/valid_v1.json')

# %%
# !zip -r "HCFA_coco_human_annotated_augmented_500.zip" "./HCFA_coco_human_annotated_augmented_500/"
# Out:
# 	zip warning: name not matched: ./HCFA_coco_human_annotated_augmented_500/
#
# zip error: Nothing to do! (try: zip -r HCFA_coco_human_annotated_augmented_500.zip . -i ./HCFA_coco_human_annotated_augmented_500/)

# %%
# !du -h /content/HCFA_coco_human_annotated_augmented_500.zip
# Out:
# 1.7G	/content/HCFA_coco_human_annotated_augmented_500.zip

# %%
# !cp -r "/content/HCFA_coco_human_annotated_augmented_500.zip" "/content/drive/MyDrive/001_projects/FSL/data/human_annotated/HCFA"

# %%
# !cp -r "/content/HCFA_coco_human_annotated_augmented_500/dataset/train_v1.json" "/content/drive/MyDrive/001_projects/FSL/data/human_annotated/HCFA"

# %% [markdown]
# ### Copy necessary image files from all images folder

# %%
# !unzip "/content/drive/MyDrive/001_projects/FSL/data/yolo_data/HCFA_data_yolo/For_Annotation_500.zip"

# %%
import os
import shutil

# Set the paths for images_all and labels folders
images_all_folder = "/content/For_Annotation_500"
labels_folder = "/content/HCFA_100_yolo/labels"
output_images_folder = "/content/images"  # This will be the new folder with images corresponding to labels

# Create the output_images_folder if it doesn't exist
os.makedirs(output_images_folder, exist_ok=True)

# Get a list of label file names without extensions
label_names = {os.path.splitext(file)[0] for file in os.listdir(labels_folder) if os.path.isfile(os.path.join(labels_folder, file))}

# Copy images from images_all to the new folder if they have corresponding labels
for label_name in label_names:
    image_path_all = os.path.join(images_all_folder, label_name + ".jpg")  # Adjust the extension as needed
    image_path_output = os.path.join(output_images_folder, label_name + ".jpg")

    if os.path.isfile(image_path_all):
        shutil.copy(image_path_all, image_path_output)
        print(f"Copied: {label_name}.jpg")

print("Image copying complete.")

# %%
len(os.listdir("/content/images"))
# Out:
# 100

# %%
# !rm -rf "/content/data"

# %%
# !cp -r "/content/images" "/content/HCFA_100_yolo"

# %%
# !zip "/content/HCFA_100_yolo" ""

# %%
# !zip -r "HCFA_100_yolo.zip" "/content/HCFA_100_yolo/"

# %% [markdown]
# # COCO Format

# %% [markdown]
# ### Load Dataset

# %%
# !zip -FF "/content/drive/MyDrive/001_projects/FSL/data/human_annotated/Dental_ADA/ADA_421_images.zip" --out "repaired.zip"
# !unzip "repaired.zip"

# %% [markdown]
# ### Only taking images that are in annotation

# %%
import json
import os
import shutil


# Path to the result.json file
result_json_path = '/content/ADA_421_images/result.json'

# Path to the images folder
images_folder_path = '/content/ADA_421_images/images'

selected_images_folder = "/content/images"

os.makedirs(selected_images_folder, exist_ok=True)
# Load the result.json file
with open(result_json_path, 'r') as json_file:
    result_data = json.load(json_file)

# Extract image filenames from the result.json file
image_filenames_in_result = [entry['file_name'] for entry in result_data['images']]

# Check if the corresponding image files exist in the images folder
existing_image_filenames = [filename for filename in image_filenames_in_result if os.path.exists(os.path.join(images_folder_path, filename.split("\\")[1]))]

# Display or use the list of existing image filenames
print(existing_image_filenames)


# Copy the existing image files to the selected images folder
for filename in existing_image_filenames:

  filename = filename.split("\\")[1]
  source_path = os.path.join(images_folder_path, filename)
  destination_path = os.path.join(selected_images_folder, filename)
  shutil.copy(source_path, destination_path)
# Out:
# ['images\\2027C467D017_001.jpg', 'images\\2027C43GD010_001.jpg', 'images\\2027C43UD020_001.jpg', 'images\\2027C48FD045_001.jpg', 'images\\2027C47TD017_001.jpg', 'images\\2027C469D005_001.jpg', 'images\\2027C45KD007_001.jpg', 'images\\2027C43TD042_001.jpg', 'images\\2027C48HD020_001.jpg', 'images\\2027C43OD010_001.jpg', 'images\\2027C43GD043_001.jpg', 'images\\2027C43ID007_001.jpg', 'images\\2027C469D029_001.jpg', 'images\\2027C43RD013_001.jpg', 'images\\2027C43ED011_001.jpg', 'images\\2027C45KD008_001.jpg', 'images\\2027C46BD002_001.jpg', 'images\\2027C43QD006_001.jpg', 'images\\2027C46DD001_001.jpg', 'images\\2027C43FD002_001.jpg', 'images\\2027C43HD021_001.jpg', 'images\\2027C43GD011_001.jpg', 'images\\2027C43KD003_001.jpg', 'images\\2027C43HD003_001.jpg', 'images\\2027C462D025_001.jpg', 'images\\2027C44YD050_001.jpg', 'images\\2027C44XD047_001.jpg', 'images\\2027C45AD047_001.jpg', 'images\\2027C43FD006_001.jpg', 'images\\2027C469D018_001.jpg', 'images\\2027C43TD008_001.jpg', 'images\\2027C43TD010_001.jpg', 'images\\2027C48HD005_001.jpg', 'images\\2027C46DD023_001.jpg', 'images\\2027C43KD010_001.jpg', 'images\\2027C44WD017_001.jpg', 'images\\2027C465D003_001.jpg', 'images\\2027C46DD019_001.jpg', 'images\\2027C463D004_001.jpg', 'images\\2027C43QD015_001.jpg', 'images\\2027C43UD009_001.jpg', 'images\\2027C43GD013_001.jpg', 'images\\2027C44XD031_001.jpg', 'images\\2027C463D007_001.jpg', 'images\\2027C45KD018_001.jpg', 'images\\2027C43SD026_001.jpg', 'images\\2027C469D014_001.jpg', 'images\\2027C44ID008_001.jpg', 'images\\2027C46BD012_001.jpg', 'images\\2027C469D001_001.jpg', 'images\\2027C43KD015_001.jpg', 'images\\2027C43HD022_001.jpg', 'images\\2027C43GD020_001.jpg', 'images\\2027C448D010_001.jpg', 'images\\2027C469D013_001.jpg', 'images\\2027C48FD022_001.jpg', 'images\\2027C43GD039_001.jpg', 'images\\2027C43OD012_001.jpg', 'images\\2027C45JD046_001.jpg', 'images\\2027C43HD005_001.jpg', 'images\\2027C469D008_001.jpg', 'images\\2027C469D023_001.jpg', 'images\\2027C46BD017_001.jpg', 'images\\2027C43GD042_001.jpg', 'images\\2027C44XD040_001.jpg', 'images\\2027C43ID009_001.jpg', 'images\\2027C46DD006_001.jpg', 'images\\2027C46BD018_001.jpg', 'images\\2027C45AD049_001.jpg', 'images\\2027C43RD011_001.jpg', 'images\\2027C43GD045_001.jpg', 'images\\2027C43ID004_001.jpg', 'images\\2027C44YD044_001.jpg', 'images\\2027C467D015_001.jpg', 'images\\2027C44WD010_001.jpg', 'images\\2027C43SD032_001.jpg', 'images\\2027C44XD037_001.jpg', 'images\\2027C43OD004_001.jpg', 'images\\2027C43HD024_001.jpg', 'images\\2027C453D009_001.jpg', 'images\\2027C43TD007_001.jpg', 'images\\2027C43GD044_001.jpg', 'images\\2027C46OD002_001.jpg', 'images\\2027C46BD019_001.jpg', 'images\\2027C43ND002_001.jpg', 'images\\2027C46DD008_001.jpg', 'images\\2027C44XD036_001.jpg', 'images\\2027C43HD010_001.jpg', 'images\\2027C43KD005_001.jpg', 'images\\2027C467D004_001.jpg', 'images\\2027C43JD001_001.jpg', 'images\\2027C48FD013_001.jpg', 'images\\2027C48GD007_001.jpg', 'images\\2027C46BD013_001.jpg', 'images\\2027C43AD013_001.jpg', 'images\\2027C43OD017_001.jpg', 'images\\2027C48HD017_001.jpg', 'images\\2027C44YD009_001.jpg', 'images\\2027C464D004_001.jpg', 'images\\2027C43SD015_001.jpg', 'images\\2027C43MD009_001.jpg', 'images\\2027C43BD003_001.jpg', 'images\\2027C43GD004_001.jpg', 'images\\2027C46DD004_001.jpg', 'images\\2027C44YD004_001.jpg', 'images\\2027C48HD027_001.jpg', 'images\\2027C48FD032_001.jpg', 'images\\2027C44XD039_001.jpg', 'images\\2027C467D019_001.jpg', 'images\\2027C44XD045_001.jpg', 'images\\2027C48FD024_001.jpg', 'images\\2027C47SD036_001.jpg', 'images\\2027C443D027_001.jpg', 'images\\2027C43QD004_001.jpg', 'images\\2027C43AD018_001.jpg', 'images\\2027C43ND008_001.jpg', 'images\\2027C45KD006_001.jpg', 'images\\2027C48FD029_001.jpg', 'images\\2027C43GD028_001.jpg', 'images\\2027C43TD013_001.jpg', 'images\\2027C43RD015_001.jpg', 'images\\2027C45KD011_001.jpg', 'images\\2027C46QD005_001.jpg', 'images\\2027C44RD005_001.jpg', 'images\\2027C43QD020_001.jpg', ...

# %%
len(existing_image_filenames)
# Out:
# 422

# %%
len(os.listdir("/content/ADA_421_images/images"))
# Out:
# 2922

# %%
import json
import os
from sklearn.model_selection import train_test_split

# Path to the result.json file
result_json_path = '/content/ADA_421_images/result.json'

# Load the result.json file
with open(result_json_path, 'r') as json_file:
    result_data = json.load(json_file)

# Extract image filenames and annotations from the result.json file
images_info = result_data['images']
annotations_info = result_data['annotations']

# Extract image filenames from the result.json file
image_filenames_in_result = [entry['file_name'] for entry in images_info]

# Split the dataset into train and validation sets
train_images, valid_images = train_test_split(image_filenames_in_result, test_size=0.01, random_state=42)

# Filter annotations for train and validation sets
train_annotations = [annotation for annotation in annotations_info if annotation['image_id'] in [entry['id'] for entry in images_info if entry['file_name'] in train_images]]
valid_annotations = [annotation for annotation in annotations_info if annotation['image_id'] in [entry['id'] for entry in images_info if entry['file_name'] in valid_images]]

# Create dictionaries for train and validation JSON files
train_json = {
    'images': [entry for entry in images_info if entry['file_name'] in train_images],
    'annotations': train_annotations,
    'categories': result_data['categories']
}

valid_json = {
    'images': [entry for entry in images_info if entry['file_name'] in valid_images],
    'annotations': valid_annotations,
    'categories': result_data['categories']
}

# Save train.json
with open('/content/train.json', 'w') as train_file:
    json.dump(train_json, train_file)

# Save valid.json
with open('/content/valid.json', 'w') as valid_file:
    json.dump(valid_json, valid_file)

# %%
import os
import cv2
import json
import albumentations as A
from pathlib import Path

# from albumentations.augmentations.bbox_utils import convert_bbox_from_albumentations, convert_bbox_to_albumentations


def convert_bbox_from_albumentations(bbox):
    x, y, width, height = bbox

    # Convert albumentations format (x, y, width, height) to COCO format (x_min, y_min, width, height)
    x_min = x
    y_min = y
    x_max = x + width
    y_max = y + height
    return [x_min, y_min, x_max, y_max]

def load_annotations(annotations_file):
    with open(annotations_file, 'r') as f:
        annotations = json.load(f)
    return annotations

def save_annotations(annotations, output_file):
    with open(output_file, 'w') as f:
        json.dump(annotations, f, indent=2)

def augment_and_save_images(images_dir, output_dir, annotations_file, num_augmentations):
    os.makedirs(output_dir, exist_ok=True)

    annotations = load_annotations(annotations_file)
    augmented_annotations = {'info': "None", 'licenses': "None", 'categories': annotations['categories'], 'images': [], 'annotations': []}

    for image_info in annotations['images']:
        image_id = image_info['id']
        image_path = os.path.join(images_dir, image_info['file_name'].split('\\')[-1])

        print("image_path", image_path)
        image = cv2.imread(image_path)
        bboxes = [ann['bbox'] for ann in annotations['annotations'] if ann['image_id'] == image_id]

        for aug_id in range(num_augmentations):
            transform = A.Compose([
                # Define your augmentations here
                A.HorizontalFlip(p=0.5),
                A.VerticalFlip(p=0.5),
                # Add more augmentations as needed
            ], bbox_params=A.BboxParams(format='coco', label_fields=['category_ids']))

            augmented = transform(image=image, bboxes=bboxes, category_ids=[1]*len(bboxes))
            augmented_image = augmented['image']

            print("boxes---->>>", augmented['bboxes'])
            augmented_bboxes = convert_bbox_from_albumentations(augmented['bboxes'])

            # Save augmented image
            augmented_image_path = os.path.join(output_dir, f"{image_id}_aug{aug_id}.jpg")
            cv2.imwrite(augmented_image_path, augmented_image)

            # Update annotations for the augmented image
            for i, ann in enumerate(annotations['annotations']):
                if ann['image_id'] == image_id:
                    new_ann = ann.copy()
                    new_ann['id'] = len(augmented_annotations['annotations']) + 1
                    new_ann['image_id'] = len(augmented_annotations['images']) + 1
                    new_ann['bbox'] = augmented_bboxes[i]
                    augmented_annotations['annotations'].append(new_ann)

            # Update image information
            augmented_image_info = image_info.copy()
            augmented_image_info['id'] = len(augmented_annotations['images']) + 1
            augmented_image_info['file_name'] = f"{image_id}_aug{aug_id}.jpg"
            augmented_annotations['images'].append(augmented_image_info)
        break
    # Save annotations to the output file
    output_annotations_file = os.path.join(output_dir, "train_augmented.json")
    save_annotations(augmented_annotations, output_annotations_file)


if __name__ == "__main__":
    images_directory = "/content/images"
    output_directory = "/content/ada_augmented_data"
    annotations_file_path = "/content/train.json"
    num_augmentations = 5  # Adjust as needed

    augment_and_save_images(images_directory, output_directory, annotations_file_path, num_augmentations)
# Out:
# image_path /content/images/2027C467D017_001.jpg
# boxes---->>> [(1023.5215113367432, 2390.4549999999836, 265.34453401021017, 50.6899999999996), (1279.4609319795752, 1501.0699999999977, 169.74906802042528, 46.69999999999982), (1560.6000000000001, 1052.4799999999993, 193.9687128834919, 50.22000000000003), (686.3920161757742, 645.7158170665075, 123.5629838242254, 58.204182933491666), (108.35197732653667, 1498.2049999999927, 209.72627208169007, 45.84999999999968), (813.2700000000001, 1244.5349999999999, 62.539999999999736, 56.67000000000007), (1279.2209319795763, 1551.389999999996, 174.09209069390022, 47.559999999999945), (1456.6074433163128, 1499.4849999999988, 171.77906802042526, 45.930000000000064), (1276.4089546530502, 1450.5249999999992, 175.73906802042552, 47.50999999999999), (542.9649999999998, 901.4850000000002, 126.50999999999976, 50.469999999999914), (1775.6674257669833, 1051.1250000000005, 157.50257423301673, 51.08999999999992), (2087.385, 759.59, 178.10999999999967, 43.24000000000001), (1459.790465989789, 1450.0849999999984, 167.8160453469493, 47.25), (104.25895465305891, 1547.5599999999927, 210.246272081694, 48.69999999999959), (1458.4539546530507, 1549.424999999998, 170.569068020425, 46.99000000000001), (500.0924433163132, 2000.494999999995, 629.9475566836891, 94.54999999999973), (106.85046598979761, 1446.099999999991, 204.68778341842915, 48.85999999999967), (2172.005931979576, 1551.8499999999972, 320.44511336737423, 45.57999999999993), (688.3500000000003, 904.9050000000002, 258.3799999999999, 46.73000000000002), (2066.455, 2598.84, 406.8899999999999, 47.960000000000036), (1153.325, 905.81, 114.43000000000006, 48.01999999999998), (967.38, 905.83, 151.81999999999982, 46.54000000000008), (1401.3561608449108, 1052.735, 142.31383915508923, 49.210000000000036), (2177.4104659897885, 1451.614999999998, 313.4405793571618, 46.430000000000064), (108.0350000000113, 2644.1499999999887, 105.35302267346607, 41.740000000002055), (1636.872909306101, 1552.2149999999933, 352.84209069390135, 46.289999999999736), (2178.845931979575, 1502.1599999999974, 313.0636020306374, 43.399999999999864), (1963.2124257669834, 1051.215, 117.85257423301664, 50.289999999999964), (682.0400000000012, 2392.934999999998, 334.0245340102116, 50.409999999999854), (908.724420642838, 2945.0749999999966, 248.420579357164, 43.67000000000007), (2106.975, 2844.94, 399.0699999999997, 38.19999999999982), (2087.9800000000005, 2888.7768802710366, 423.5799999999995, 44.983119728962265), (1522.409355505094, 1958.176287436013, 1005.5022370459333, 141.39999999999918), (2094.655271776776, 210.1309903214329, 407.399728223224, 45.41999999999996), (1637.1604659897912, 1450.4999999999907, 356.7790680204225, 45.399999999999636), (636.0018108552773, 2490.4299999999944, 374.5731891447243, 54.07999999999993), (2048.65, 2403.97, 433.8199999999997, 45.820000000000164), (1034.08, 1952.4450000000008, 94.90000000000009, 44.489999999999554), (2324.785, 761.4250000000002, 195.59000000000015, 41.710000000000036), (506.2193072754703, 2651.3849999999784, 389.13045346949764, 38.00999999999976), (813.7000000000002, 645.75, 61.67999999999995, 57.89999999999998), (111.96656848328443, 2486.064999999991, 510.85098820040486, 56.2418323592492), (2099.2845048392837, 260.63549516071646, 399.6399999999999, 44.620000000000005), (598.5319773265261, 2581.3399999999992, 225.75000000000023, 64.65999999999985), (914.3799999999998, 2590.87, 358.32000000000005, 53.48000000000002), (451.3850000000069, 3092.674999999992, 803.7387153980054, 44.23000000000002), (106.96697732653678, 2043.3549999999861, 225.14987411232698, 49.80999999999972), (1637.9804659897882, 1502.1099999999985, 351.8375566836871, 44.179999999999836), (2100.6841092038017, 1047.669999999998, 424.3060392622315, 54.63128711650825), (2088.19, 1500.83, 83.87999999999965, 45.11999999999989), (1731.8350500811514, 2945.3999999999464, 776.8899499188503, 43.41999999999916), (280.43348866326784, 2580.065320406551, 244.00999999999937, 60.12623945792893), (1418.5445048392835, 206.44936895089558, 602.06, 52.6 ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-3412023712bc> in <cell line: 81>()
#      85     num_augmentations = 5  # Adjust as needed
#      86
# ---> 87     augment_and_save_images(images_directory, output_directory, annotations_file_path, num_augmentations)
#
# <ipython-input-66-3412023712bc> in augment_and_save_images(images_dir, output_dir, annotations_file, num_augmentations)
#      53
#      54             print("boxes---->>>", augmented['bboxes'])
# ---> 55             augmented_bboxes = convert_bbox_from_albumentations(augmented['bboxes'])
#      56
#      57             # Save augmented image
#
# <ipython-input-66-3412023712bc> in convert_bbox_from_albumentations(bbox)
#       9
#      10 def convert_bbox_from_albumentations(bbox):
# ---> 11     x, y, width, height = bbox
#      12
#      13     # Convert albumentations format (x, y, width, height) to COCO format (x_min, y_min, width, height)
#
# ValueError: too many values to unpack (expected 4)

# %%
import albumentations.augmentations.bbox_utils
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-49-0c5a6b553c26> in <cell line: 1>()
# ----> 1 import albumentations.augmentations.bbox_utils
#
# ModuleNotFoundError: No module named 'albumentations.augmentations.bbox_utils'

# %%
load_annotations(annotations_file_path)
# Out:
# {'images': [{'width': 2602,
#    'height': 3360,
#    'id': 0,
#    'file_name': 'images\\2027C467D017_001.jpg'},
#   {'width': 2603,
#    'height': 3348,
#    'id': 1,
#    'file_name': 'images\\2027C43GD010_001.jpg'},
#   {'width': 2635,
#    'height': 3391,
#    'id': 2,
#    'file_name': 'images\\2027C43UD020_001.jpg'},
#   {'width': 2599,
#    'height': 3350,
#    'id': 3,
#    'file_name': 'images\\2027C48FD045_001.jpg'},
#   {'width': 2594,
#    'height': 3358,
#    'id': 4,
#    'file_name': 'images\\2027C47TD017_001.jpg'},
#   {'width': 2599,
#    'height': 3357,
#    'id': 5,
#    'file_name': 'images\\2027C469D005_001.jpg'},
#   {'width': 2604,
#    'height': 3359,
#    'id': 6,
#    'file_name': 'images\\2027C45KD007_001.jpg'},
#   {'width': 2596,
#    'height': 3360,
#    'id': 7,
#    'file_name': 'images\\2027C43TD042_001.jpg'},
#   {'width': 2599,
#    'height': 3354,
#    'id': 8,
#    'file_name': 'images\\2027C48HD020_001.jpg'},
#   {'width': 2595,
#    'height': 3360,
#    'id': 9,
#    'file_name': 'images\\2027C43OD010_001.jpg'},
#   {'width': 2599,
#    'height': 3363,
#    'id': 10,
#    'file_name': 'images\\2027C43GD043_001.jpg'},
#   {'width': 2598,
#    'height': 3348,
#    'id': 11,
#    'file_name': 'images\\2027C43ID007_001.jpg'},
#   {'width': 2605,
#    'height': 3364,
#    'id': 12,
#    'file_name': 'images\\2027C469D029_001.jpg'},
#   {'width': 2603,
#    'height': 3359,
#    'id': 13,
#    'file_name': 'images\\2027C43RD013_001.jpg'},
#   {'width': 2605,
#    'height': 3344,
#    'id': 14,
#    'file_name': 'images\\2027C43ED011_001.jpg'},
#   {'width': 2611,
#    'height': 3371,
#    'id': 15,
#    'file_name': 'images\\2027C45KD008_001.jpg'},
#   {'width': 2599,
#    'height': 3360,
#    'id': 16,
#    'file_name': 'images\\2027C46BD002_001.jpg'},
#   {'width': 2624,
#    'height': 3377,
#    'id': 17,
#    'file_name': 'images\\2027C43QD006_001.jpg'},
#   {'width': 2644,
#    'height': 3395,
#    'id': 18,
#    'file_name': 'images\\2027C46DD001_001.jpg'},
#   {'width': 2602,
#    'height': 3353,
#    'id': 19,
#    'file_name': 'images\\2027C43FD002_001.jpg'},
#   {'width': 2596,
#    'height': 3347,
#    'id': 20,
#    'file_name': 'images\\2027C43HD021_001.jpg'},
#   {'width': 2606,
#    'height': 3343,
#    'id': 21,
#    'file_name': 'images\\2027C43GD011_001.jpg'},
#   {'width': 2618,
#    'height': 3365,
#    'id': 22,
#    'file_name': 'images\\2027C43KD003_001.jpg'},
#   {'width': 2608,
#    'height': 3355,
#    'id': 23,
#    'file_name': 'images\\2027C43HD003_001.jpg'},
#   {'width': 2599,
#    'height': 3363,
#    'id': 24,
#    'file_name': 'images\\2027C462D025_001.jpg'},
#   {'width': 2598,
#    'height': 3353,
#    'id': 25,
#    'file_name': 'images\\2027C44YD050_001.jpg'},
#   {'width': 2596,
#    'height': 3352,
#    'id': 26,
#    'file_name': 'images\\2027C44XD047_001.jpg'},
#   {'width': 2603,
#    'height': 3365,
#    'id': 27,
#    'file_name': 'images\\2027C45AD047_001.jpg'},
#   {'width': 2598,
#    'height': 3350,
#    'id': 28,
#    'file_name': 'images\\2027C43FD006_001.jpg'},
#   {'width': 2593,
#    'height': 3357,
#    'id': 29,
#    'file_name': 'images\\2027C469D018_001.jpg'},
#   {'width': 2600,
#    'height': 3364,
#    'id': 30,
#    'file_name': 'images\\2027C43TD008_001.jpg'},
#   {'width': 2606,
#    'height': 3364,
#    'id': 31,
#    'file_name': 'images\\2027C43TD010_001.jpg'},
#   {'width': 2597,
#    'height': 3357,
#    'id': 32,
#    'file_name': 'images\\2027C48HD005_001.jpg'},
#   {'width': 2587,
#    'height': 3324,
#    'id': 33,
#    'file_name': 'images\\2027C46DD023_001.jpg'},
#   {'width': 2598,
#    'height': 3355,
#    'id': 34,
#    'file_name': 'images\\2027C43KD010_001.jpg'},
#   {'width': 2609,
#    'height': 3376,
#    'id': 35,
#    'file_name': 'images\\2027C44WD017_001.jpg'},
#   {'width': 2601,
#    'height': 3361,
#    'id': 36,
#    'file_name': 'images\\2027C465D003_001.jpg'},
#   {'width': 2580,
#    'height': 3330,
#    'id': 37,
#    'file_name': 'images\\2027C46DD019_001.jpg'},
#   {'width': 2604,
#    'height': 3363,
#    'id': 38,
#    'file_name': 'images\\2027C463D004_001.jpg'},
#   {'width': 2596,
#    'height': 3360,
#    'id': 39,
#    'file_name': 'images\\2027C43QD015_001.jpg'},
#   {'width': 2601,
#    'height': 3357,
#    'id': 40,
#    'file_name': 'images\\2027C43UD009_001.jpg'},
#   {'width': 2603,
#    'height': 3347,
#    'id': 41,
#    'file_name': 'images\\2027C43GD013_001.jpg'},
#   {'width': 2595,
#    'height': 3361,
#    'id': 42,
#    'file_name': 'images\\2027C44XD031_001.jpg'},
#   {'width': 2600,
#    'height': 3353,
#    'id': 43,
#    'file_name': 'images\\2027C463D007_001.jpg'},
#   {'width': 2601,
#    'height': 3362,
#    'id': 44,
#    'file_name': 'images\\2027C45KD018_001.jpg'},
#   {'width': 2605,
#    'height': 3359,
#    'id': 45,
#    'file_name': 'images\\2027C43SD026_001.jpg'},
#   {'width': 2603,
#    'height': 3362,
#    'id': 46,
#    'file_name': 'images\\2027C469D014_001.jpg'},
#   {'width': 2617,
#    'height': 3354,
#    'id': 47,
#    'file_name': 'images\\2027C44ID008_001.jpg'},
#   {'width': 2603,
#    'height': 3361,
#    'id': 48,
#    'file_name': 'images\\2027C46BD012_001.jpg'},
#   {'width': 2606,
#    'height': 3372,
#    'id': 49,
#    'file_name': 'images\\2027C469D001_001.jpg'},
#   {'width': 2619,
#    'height': 3364,
#    'id': 50,
#    'file_name': 'images\\2027C43KD015_001.jpg'},
#   {'width': 2602,
#    'height': 3353,
#    'id': 51,
#    'file_name': 'images\\2027C43HD022_001.jpg'},
#   {'width': 2606,
#    'height': 3354,
#    'id': 52,
#    'file_name': 'images\\2027C43GD020_001.jpg'},
#   {'width': 2616,
#    'height': 3375,
#    'id': 53,
#    'file_name': 'images\\2027C448D010_001.jpg'},
#   {'width': 2621,
#    'height': 3371,
#    'id': 54,
#    'file_name': 'images\\2027C469D013_001.jpg'},
#   {'width': 2601,
#    'height': 3371,
#    'id': 55,
#    'file_name': 'images\\2027C48FD022_001.jpg'},
#   {'width': 2604,
#    'height': 3345,
#    'id': 56,
#    'file_name': 'images\\2027C43GD039_001.jpg'},
#   {'width': 2596,
#    'height': 3366,
#    'id': 57,
#    'file_name': 'images\\2027C43OD012_001.jpg'},
#   {'width': 2596,
#    'height': 3345,
#    'id': 58,
#    'file_name': 'images\\2027C45JD046_001.jpg'},
#   {'width': 2611,
#    'height': 3357,
#    'id': 59,
#    'file_name': 'images\\2027C43HD005_001.jpg'},
#   {'width': 2593,
#    'height': 3366,
#    'id': 60,
#    'file_name': 'images\\2027C469D008_001.jpg'},
#   {'width': 2591,
#    'height': 3362,
#    'id': 61,
#    'file_name': 'images\\2027C469D023_001.jpg'},
#   {'width': 2600,
#    'height': 3363,
#    'id': 62,
#    'file_name': 'images\\2027C46BD017_001.jpg'},
#   {'width': 2598,
#    'height': 3353,
#    'id': 63,
#    'file_name': 'images\\2027C43GD042_001.jpg'},
#   {'width': 2599,
#    'height': 3357,
#    'id': 64,
#    'file_name': 'images\\2027C44XD040_001.jpg'},
#   {'width': 2604,
#    'height': 3353,
#    'id': 65,
#    'file_name': 'images\\2027C43ID009_001.jpg'},
#   {'width': 2600,
#    'height': 3363,
#    'id': 66,
#    'file_name': 'images\\2027C46DD006_001.jpg'},
#   {'width': 2605,
#    'height': 3361,
#    'id': 67,
#    'file_name': 'images\\2027C46BD018_001.jpg'},
#   {'width': 2597,
#    'height': 3358,
#    'id': 68,
#    'file_name': 'images\\2027C45AD049_001.jpg'},
#   {'width': 2593,
#    'height': 3362,
#    'id': 69,
#    'file_name': 'images\\2027C43RD011_001.jpg'},
#   {'width': 2612,
#    'height': 3361,
#    'id': 70,
#    'file_name': 'images\\2027C43GD045_001.jpg'},
#   {'width': 2601,
#    'height': 3352,
#    'id': 71,
#    'file_name': 'images\\2027C43ID004_001.jpg'},
#   {'width': 2596,
#    'height': 3352,
#    'id': 72,
#    'file_name': 'images\\2027C44YD044_001.jpg'},
#   {'width': 2597,
#    'height': 3357,
#    'id': 73,
#    'file_name': 'images\\2027C467D015_001.jpg'},
#   {'width': 2606,
#    'height': 3357,
#    'id': 74,
#    'file_name': 'images\\2027C44WD010_001.jpg'},
#   {'width': 2595,
#    'height': 3369,
#    'id': 75,
#    'file_name': 'images\\2027C43SD032_001.jpg'},
#   {'width': 2601,
#    'height': 3358,
#    'id': 76,
#    'file_name': 'images\\2027C44XD037_001.jpg'},
#   {'width': 2629,
#    'height': 3367,
#    'id': 77,
#    'file_name': 'images\\2027C43OD004_001.jpg'},
#   {'width': 2615,
#    'height': 3355,
#    'id': 78,
#    'file_name': 'images\\2027C43HD024_001.jpg'},
#   {'width': 2601,
#    'height': 3355,
#    'id': 79,
#    'file_name': 'images\\2027C453D009_001.jpg'},
#   {'width': 2593,
#    'height': 3363,
#    'id': 80,
#    'file_name': 'images\\2027C43TD007_001.jpg'},
#   {'width': 2603,
#    'height': 3343,
#    'id': 81,
#    'file_name': 'images\\2027C43GD044_001.jpg'},
#   {'width': 2587,
#    'height': 3334,
#    'id': 82,
#    'file_name': 'images\\2027C46OD002_001.jpg'},
#   {'width': 2594,
#    'height': 3319,
#    'id': 83,
#    'file_name': 'images\\2027C46BD019_001.jpg'},
#   {'width': 2612,
#    'height': 3364,
#    'id': 84,
#    'file_name': 'images\\2027C43ND002_001.jpg'},
#   {'width': 2602,
#    'height': 3360,
#    'id': 85,
#    'file_name': 'images\\2027C46DD008_001.jpg'},
#   {'width': 2603,
#    'height': 3368,
#    'id': 86,
#    'file_name': 'images\\2027C44XD036_001.jpg'},
#   {'width': 2602,
#    'height': 3342,
#    'id': 87,
#    'file_name': 'images\\2027C43HD010_001.jpg'},
#   {'width': 2604,
#    'height': 3346,
#    'id': 88,
#    'file_name': 'images\\2027C43KD005_001.jpg'},
#   {'width': 2594,
#    'height': 3361,
#    'id': 89,
#    'file_name': 'images\\2027C467D004_001.jpg'},
#   {'width': 2610,
#    'height': 3355,
#    'id': 90,
#    'file_name': 'images\\2027C43JD001_001.jpg'},
#   {'width': 2585,
#    'height': 3353,
#    'id': 91,
#    'file_name': 'images\\2027C48FD013_001.jpg'},
#   {'width': 2624,
#    'height': 3374,
#    'id': 92,
#    'file_name': 'images\\2027C48GD007_001.jpg'},
#   {'width': 2597,
#    'height': 3359,
#    'id': 93,
#    'file_name': 'images\\2027C46BD013_001.jpg'},
#   {'width': 2604,
#    'height': 3349,
#    'id': 94,
#    'file_name': 'images\\2027C43AD013_001.jpg'},
#   {'width': 2599,
#    'height': 3357,
#    'id': 95,
#    'file_name': 'images\\2027C43OD017_001.jpg'},
#   {'width': 2616,
#    'height': 3368,
#    'id': 96,
#    'file_name': 'images\\2027C48HD017_001.jpg'},
#   {'width': 2594,
#    'height': 3355,
#    'id': 97,
#    'file_name': 'images\\2027C44YD009_001.jpg'},
#   {'width': 2607,
#    'height': 3366,
#    'id': 98,
#    'file_name': 'images\\2027C464D004_001.jpg'},
#   {'width': 2603,
#    'height': 3362,
#    'id': 99,
#    'file_name': 'images\\2027C43SD015_001.jpg'},
#   {'width': 2608,
#    'height': 3356,
#    'id': 100,
#    'file_name': 'images\\2027C43MD009_001.jpg'},
#   {'width': 2611,
#    'height': 3351,
#    'id': 101,
#    'file_name': 'images\\2027C43BD003_001.jpg'},
#   {'width': 2604,
#    'height': 3358,
#    'id': 102,
#    'file_name': 'images\\2027C43GD004_001.jpg'},
#   {'width': 2608,
#    'height': 3366,
#    'id': 103,
#    'file_name': 'images\\2027C46DD004_001.jpg'},
#   {'width': 2590,
#    'height': 3362,
#    'id': 104,
#    'file_name': 'images\\2027C44YD004_001.jpg'},
#   {'width': 2596,
#    'height': 3362,
#    'id': 105,
#    'file_name': 'images\\2027C48HD027_001.jpg'},
#   {'width': 2603,
#    'height': 3351,
#    'id': 106,
#    'file_name': 'images\\2027C48FD032_001.jpg'},
#   {'width': 2604,
#    'height': 3363,
#    'id': 107,
#    'file_name': 'images\\2027C44XD039_001.jpg'},
#   {'width': 2599,
#    'height': 3364,
#    'id': 108,
#    'file_name': 'images\\2027C467D019_001.jpg'},
#   {'width': 2599,
#    'height': 3360,
#    'id': 109,
#    'file_name': 'images\\2027C44XD045_001.jpg'},
#   {'width': 2597,
#    'height': 3355,
#    'id': 110,
#    'file_name': 'images\\2027C48FD024_001.jpg'},
#   {'width': 2601,
#    'height': 3368,
#    'id': 111,
#    'file_name': 'images\\2027C47SD036_001.jpg'},
#   {'width': 2594,
#    'height': 3360,
#    'id': 112,
#    'file_name': 'images\\2027C443D027_001.jpg'},
#   {'width': 2592,
#    'height': 3366,
#    'id': 113,
#    'file_name': 'images\\2027C43QD004_001.jpg'},
#   {'width': 2597,
#    'height': 3351,
#    'id': 114,
#    'file_name': 'images\\2027C43AD018_001.jpg'},
#   {'width': 2611,
#    'height': 3352,
#    'id': 115,
#    'file_name': 'images\\2027C43ND008_001.jpg'},
#   {'width': 2603,
#    'height': 3362,
#    'id': 116,
#    'file_name': 'images\\2027C45KD006_001.jpg'},
#   {'width': 2599,
#    'height': 3359,
#    'id': 117,
#    'file_name': 'images\\2027C48FD029_001.jpg'},
#   {'width': 2616,
#    'height': 3361,
#    'id': 118,
#    'file_name': 'images\\2027C43GD028_001.jpg'},
#   {'width': 2602,
#    'height': 3359,
#    'id': 119,
#    'file_name': 'images\\2027C43TD013_001.jpg'},
#   {'width': 2598,
#    'height': 3362,
#    'id': 120,
#    'file_name': 'images\\2027C43RD015_001.jpg'},
#   {'width': 2598,
#    'height': 3357,
#    'id': 121,
#    'file_name': 'images\\2027C45KD011_001.jpg'},
#   {'width': 2604,
#    'height': 3333,
#    'id': 122,
#    'file_name': 'images\\2027C46QD005_001.jpg'},
#   {'width': 2605,
#    'height': 3359,
#    'id': 123,
#    'file_name': 'images\\2027C44RD005_001.jpg'},
#   {'width': 2608,
#    'height': 3373,
#    'id': 124,
#    'file_name': 'images\\2027C43QD020_001.jpg'},
#   {'width': 2606,
#    'height': 3349,
#    'id': 125,
#    'file_name': 'images\\2027C44YD045_001.jpg'},
#   {'width': 2613,
#    'height': 3366,
#    'id': 126,
#    'file_name': 'images\\2027C44XD024_001.jpg'},
#   {'width': 2626,
#    'height': 3366,
#    'id': 127,
#    'file_name': 'images\\2027C450D024_001.jpg'},
#   {'width': 2598,
#    'height': 3361,
#    'id': 128,
#    'file_name': 'images\\2027C44XD002_001.jpg'},
#   {'width': 2594,
#    'height': 3359,
#    'id': 129,
#    'file_name': 'images\\2027C44XD044_001.jpg'},
#   {'width': 2618,
#    'height': 3379,
#    'id': 130,
#    'file_name': 'images\\2027C44XD049_001.jpg'},
#   {'width': 2596,
#    'height': 3342,
#    'id': 131,
#    'file_name': 'images\\2027C46DD021_001.jpg'},
#   {'width': 2613,
#    'height': 3351,
#    'id': 132,
#    'file_name': 'images\\2027C43PD003_001.jpg'},
#   {'width': 2604,
#    'height': 3362,
#    'id': 133,
#    'file_name': 'images\\2027C44WD008_001.jpg'},
#   {'width': 2604,
#    'height': 3348,
#    'id': 134,
#    'file_name': 'images\\2027C48GD002_001.jpg'},
#   {'width': 2597,
#    'height': 3357,
#    'id': 135,
#    'file_name': 'images\\2027C45BD005_001.jpg'},
#   {'width': 2600,
#    'height': 3359,
#    'id': 136,
#    'file_name': 'images\\2027C44YD046_001.jpg'},
#   {'width': 2610,
#    'height': 3366,
#    'id': 137,
#    'file_name': 'images\\2027C43HD027_001.jpg'},
#   {'width': 2602,
#    'height': 3343,
#    'id': 138,
#    'file_name': 'images\\2027C46QD008_001.jpg'},
#   {'width': 2603,
#    'height': 3371,
#    'id': 139,
#    'file_name': 'images\\2027C46DD009_001.jpg'},
#   {'width': 2599,
#    'height': 3355,
#    'id': 140,
#    'file_name': 'images\\2027C463D002_001.jpg'},
#   {'width': 2610,
#    'height': 3353,
#    'id': 141,
#    'file_name': 'images\\2027C44YD033_001.jpg'},
#   {'width': 2609,
#    'height': 3351,
#    'id': 142,
#    'file_name': 'images\\2027C43ID013_001.jpg'},
#   {'width': 2620,
#    'height': 3386,
#    'id': 143,
#    'file_name': 'images\\2027C46DD011_001.jpg'},
#   {'width': 2596,
#    'height': 3348,
#    'id': 144,
#    'file_name': 'images\\2027C48FD048_001.jpg'},
#   {'width': 2599,
#    'height': 3351,
#    'id': 146,
#    'file_name': 'images\\2027C43ID012_001.jpg'},
#   {'width': 2608,
#    'height': 3361,
#    'id': 147,
#    'file_name': 'images\\2027C43TD016_001.jpg'},
#   {'width': 2606,
#    'height': 3369,
#    'id': 148,
#    'file_name': 'images\\2027C469D016_001.jpg'},
#   {'width': 2603,
#    'height': 3366,
#    'id': 149,
#    'file_name': 'images\\2027C46BD011_001.jpg'},
#   {'width': 2597,
#    'height': 3361,
#    'id': 150,
#    'file_name': 'images\\2027C43HD020_001.jpg'},
#   {'width': 2609,
#    'height': 3353,
#    'id': 151,
#    'file_name': 'images\\2027C43KD009_001.jpg'},
#   {'width': 2600,
#    'height': 3359,
#    'id': 152,
#    'file_name': 'images\\2027C467D014_001.jpg'},
#   {'width': 2598,
#    'height': 3358,
#    'id': 153,
#    'file_name': 'images\\2027C469D004_001.jpg'},
#   {'width': 2599,
#    'height': 3362,
#    'id': 154,
#    'file_name': 'images\\2027C43SD003_001.jpg'},
#   {'width': 2596,
#    'height': 3357,
#    'id': 155,
#    'file_name': 'images\\2027C467D020_001.jpg'},
#   {'width': 2605,
#    'height': 3356,
#    'id': 156,
#    'file_name': 'images\\2027C43UD001_001.jpg'},
#   {'width': 2594,
#    'height': 3357,
#    'id': 157,
#    'file_name': 'images\\2027C43TD009_001.jpg'},
#   {'width': 2600,
#    'height': 3353,
#    'id': 158,
#    'file_name': 'images\\2027C45AD048_001.jpg'},
#   {'width': 2611,
#    'height': 3354,
#    'id': 159,
#    'file_name': 'images\\2027C44YD048_001.jpg'},
#   {'width': 2603,
#    'height': 3346,
#    'id': 160,
#    'file_name': 'images\\2027C47CD024_001.jpg'},
#   {'width': 2600,
#    'height': 3357,
#    'id': 161,
#    'file_name': 'images\\2027C45AD034_001.jpg'},
#   {'width': 2591,
#    'height': 3341,
#    'id': 162,
#    'file_name': 'images\\2027C46OD004_001.jpg'},
#   {'width': 2612,
#    'height': 3368,
#    'id': 163,
#    'file_name': 'images\\2027C46DD002_001.jpg'},
#   {'width': 2604,
#    'height': 3353,
#    'id': 164,
#    'file_name': 'images\\2027C43GD002_001.jpg'},
#   {'width': 2597,
#    'height': 3351,
#    'id': 165,
#    'file_name': 'images\\2027C43UD003_001.jpg'},
#   {'width': 2597,
#    'height': 3349,
#    'id': 166,
#    'file_name': 'images\\2027C43FD009_001.jpg'},
#   {'width': 2597,
#    'height': 3361,
#    'id': 167,
#    'file_name': 'images\\2027C467D027_001.jpg'},
#   {'width': 2598,
#    'height': 3366,
#    'id': 168,
#    'file_name': 'images\\2027C43OD013_001.jpg'},
#   {'width': 2603,
#    'height': 3360,
#    'id': 169,
#    'file_name': 'images\\2027C48FD031_001.jpg'},
#   {'width': 2602,
#    'height': 3367,
#    'id': 170,
#    'file_name': 'images\\2027C46DD014_001.jpg'},
#   {'width': 2595,
#    'height': 3361,
#    'id': 171,
#    'file_name': 'images\\2027C43OD016_001.jpg'},
#   {'width': 2597,
#    'height': 3358,
#    'id': 172,
#    'file_name': 'images\\2027C469D015_001.jpg'},
#   {'width': 2612,
#    'height': 3358,
#    'id': 173,
#    'file_name': 'images\\2027C43ID008_001.jpg'},
#   {'width': 2612,
#    'height': 3347,
#    'id': 174,
#    'file_name': 'images\\2027C452D003_001.jpg'},
#   {'width': 2599,
#    'height': 3363,
#    'id': 176,
#    'file_name': 'images\\2027C43UD019_001.jpg'},
#   {'width': 2618,
#    'height': 3360,
#    'id': 177,
#    'file_name': 'images\\2027C43FD005_001.jpg'},
#   {'width': 2595,
#    'height': 3364,
#    'id': 178,
#    'file_name': 'images\\2027C45BD011_001.jpg'},
#   {'width': 2596,
#    'height': 3358,
#    'id': 179,
#    'file_name': 'images\\2027C46BD003_001.jpg'},
#   {'width': 2613,
#    'height': 3363,
#    'id': 180,
#    'file_name': 'images\\2027C43SD030_001.jpg'},
#   {'width': 2591,
#    'height': 3358,
#    'id': 181,
#    'file_name': 'images\\2027C43SD020_001.jpg'},
#   {'width': 2599,
#    'height': 3357,
#    'id': 182,
#    'file_name': 'images\\2027C43TD029_001.jpg'},
#   {'width': 2607,
#    'height': 3345,
#    'id': 183,
#    'file_name': 'images\\2027C48FD039_001.jpg'},
#   {'width': 2590,
#    'height': 3355,
#    'id': 184,
#    'file_name': 'images\\2027C464D001_001.jpg'},
#   {'width': 2601,
#    'height': 3368,
#    'id': 185,
#    'file_name': 'images\\2027C43QD003_001.jpg'},
#   {'width': 2610,
#    'height': 3347,
#    'id': 186,
#    'file_name': 'images\\2027C43ID019_001.jpg'},
#   {'width': 2608,
#    'height': 3352,
#    'id': 187,
#    'file_name': 'images\\2027C43GD047_001.jpg'},
#   {'width': 2597,
#    'height': 3353,
#    'id': 188,
#    'file_name': 'images\\2027C44XD048_001.jpg'},
#   {'width': 2614,
#    'height': 3375,
#    'id': 189,
#    'file_name': 'images\\2027C45KD015_001.jpg'},
#   {'width': 2590,
#    'height': 3358,
#    'id': 190,
#    'file_name': 'images\\2027C45BD007_001.jpg'},
#   {'width': 2605,
#    'height': 3367,
#    'id': 191,
#    'file_name': 'images\\2027C43OD021_001.jpg'},
#   {'width': 2606,
#    'height': 3372,
#    'id': 192,
#    'file_name': 'images\\2027C46DD012_001.jpg'},
#   {'width': 2605,
#    'height': 3366,
#    'id': 193,
#    'file_name': 'images\\2027C467D018_001.jpg'},
#   {'width': 2612,
#    'height': 3354,
#    'id': 194,
#    'file_name': 'images\\2027C44YD049_001.jpg'},
#   {'width': 2598,
#    'height': 3330,
#    'id': 195,
#    'file_name': 'images\\2027C46QD007_001.jpg'},
#   {'width': 2597,
#    'height': 3361,
#    'id': 196,
#    'file_name': 'images\\2027C45DD042_001.jpg'},
#   {'width': 2591,
#    'height': 3340,
#    'id': 197,
#    'file_name': 'images\\2027C46OD003_001.jpg'},
#   {'width': 2596,
#    'height': 3365,
#    'id': 198,
#    'file_name': 'images\\2027C43TD041_001.jpg'},
#   {'width': 2598,
#    'height': 3328,
#    'id': 199,
#    'file_name': 'images\\2027C46HD001_001.jpg'},
#   {'width': 2619,
#    'height': 3373,
#    'id': 200,
#    'file_name': 'images\\2027C43ID002_001.jpg'},
#   {'width': 2593,
#    'height': 3364,
#    'id': 201,
#    'file_name': 'images\\2027C43TD030_001.jpg'},
#   {'width': 2602,
#    'height': 3366,
#    'id': 202,
#    'file_name': 'images\\2027C44WD007_001.jpg'},
#   {'width': 2606,
#    'height': 3362,
#    'id': 203,
#    'file_name': 'images\\2027C47WD007_001.jpg'},
#   {'width': 2598,
#    'height': 3356,
#    'id': 204,
#    'file_name': 'images\\2027C43RD018_001.jpg'},
#   {'width': 2604,
#    'height': 3349,
#    'id': 205,
#    'file_name': 'images\\2027C43ND011_001.jpg'},
#   {'width': 2613,
#    'height': 3385,
#    'id': 206,
#    'file_name': 'images\\2027C46KD001_001.jpg'},
#   {'width': 2604,
#    'height': 3352,
#    'id': 207,
#    'file_name': 'images\\2027C43MD010_001.jpg'},
#   {'width': 2605,
#    'height': 3357,
#    'id': 208,
#    'file_name': 'images\\2027C43LD009_001.jpg'},
#   {'width': 2583,
#    'height': 3332,
#    'id': 209,
#    'file_name': 'images\\2027C46DD020_001.jpg'},
#   {'width': 2604,
#    'height': 3362,
#    'id': 210,
#    'file_name': 'images\\2027C44QD024_001.jpg'},
#   {'width': 2593,
#    'height': 3362,
#    'id': 211,
#    'file_name': 'images\\2027C469D020_001.jpg'},
#   {'width': 2597,
#    'height': 3384,
#    'id': 212,
#    'file_name': 'images\\2027C44XD035_001.jpg'},
#   {'width': 2611,
#    'height': 3364,
#    'id': 213,
#    'file_name': 'images\\2027C48FD025_001.jpg'},
#   {'width': 2600,
#    'height': 3360,
#    'id': 214,
#    'file_name': 'images\\2027C43SD001_001.jpg'},
#   {'width': 2600,
#    'height': 3332,
#    'id': 215,
#    'file_name': 'images\\2027C46BD020_001.jpg'},
#   {'width': 2583,
#    'height': 3323,
#    'id': 216,
#    'file_name': 'images\\2027C470D002_001.jpg'},
#   {'width': 2602,
#    'height': 3356,
#    'id': 217,
#    'file_name': 'images\\2027C45YD001_001.jpg'},
#   {'width': 2602,
#    'height': 3363,
#    'id': 218,
#    'file_name': 'images\\2027C44XD038_001.jpg'},
#   {'width': 2599,
#    'height': 3360,
#    'id': 219,
#    'file_name': 'images\\2027C43OD001_001.jpg'},
#   {'width': 2599,
#    'height': 3361,
#    'id': 220,
#    'file_name': 'images\\2027C43KD006_001.jpg'},
#   {'width': 2622,
#    'height': 3361,
#    'id': 221,
#    'file_name': 'images\\2027C43AD001_001.jpg'},
#   {'width': 2618,
#    'height': 3374,
#    'id': 222,
#    'file_name': 'images\\2027C442D024_001.jpg'},
#   {'width': 2595,
#    'height': 3355,
#    'id': 223,
#    'file_name': 'images\\2027C45KD016_001.jpg'},
#   {'width': 2596,
#    'height': 3370,
#    'id': 224,
#    'file_name': 'images\\2027C441D008_001.jpg'},
#   {'width': 2597,
#    'height': 3361,
#    'id': 225,
#    'file_name': 'images\\2027C453D002_001.jpg'},
#   {'width': 2598,
#    'height': 3365,
#    'id': 226,
#    'file_name': 'images\\2027C45FD002_001.jpg'},
#   {'width': 2590,
#    'height': 3341,
#    'id': 227,
#    'file_name': 'images\\2027C46DD018_001.jpg'},
#   {'width': 2611,
#    'height': 3348,
#    'id': 228,
#    'file_name': 'images\\2027C43GD009_001.jpg'},
#   {'width': 2603,
#    'height': 3351,
#    'id': 229,
#    'file_name': 'images\\2027C43BD004_001.jpg'},
#   {'width': 2594,
#    'height': 3363,
#    'id': 230,
#    'file_name': 'images\\2027C43TD043_001.jpg'},
#   {'width': 2603,
#    'height': 3363,
#    'id': 231,
#    'file_name': 'images\\2027C45FD019_001.jpg'},
#   {'width': 2596,
#    'height': 3358,
#    'id': 232,
#    'file_name': 'images\\2027C467D012_001.jpg'},
#   {'width': 2591,
#    'height': 3374,
#    'id': 233,
#    'file_name': 'images\\2027C43RD020_001.jpg'},
#   {'width': 2594,
#    'height': 3327,
#    'id': 234,
#    'file_name': 'images\\2027C46QD006_001.jpg'},
#   {'width': 2595,
#    'height': 3363,
#    'id': 235,
#    'file_name': 'images\\2027C43TD045_001.jpg'},
#   {'width': 2610,
#    'height': 3363,
#    'id': 236,
#    'file_name': 'images\\2027C48FD018_001.jpg'},
#   {'width': 2602,
#    'height': 3359,
#    'id': 237,
#    'file_name': 'images\\2027C450D015_001.jpg'},
#   {'width': 2594,
#    'height': 3363,
#    'id': 238,
#    'file_name': 'images\\2027C46BD008_001.jpg'},
#   {'width': 2608,
#    'height': 3360,
#    'id': 239,
#    'file_name': 'images\\2027C43RD001_001.jpg'},
#   {'width': 2603,
#    'height': 3345,
#    'id': 240,
#    'file_name': 'images\\2027C43LD005_001.jpg'},
#   {'width': 2604,
#    'height': 3348,
#    'id': 241,
#    'file_name': 'images\\2027C43ED012_001.jpg'},
#   {'width': 2623,
#    'height': 3369,
#    'id': 242,
#    'file_name': 'images\\2027C43HD019_001.jpg'},
#   {'width': 2578,
#    'height': 3330,
#    'id': 243,
#    'file_name': 'images\\2027C46MD002_001.jpg'},
#   {'width': 2605,
#    'height': 3349,
#    'id': 244,
#    'file_name': 'images\\2027C43ND007_001.jpg'},
#   {'width': 2598,
#    'height': 3365,
#    'id': 245,
#    'file_name': 'images\\2027C48FD014_001.jpg'},
#   {'width': 2606,
#    'height': 3360,
#    'id': 246,
#    'file_name': 'images\\2027C489D004_001.jpg'},
#   {'width': 2607,
#    'height': 3370,
#    'id': 247,
#    'file_name': 'images\\2027C469D024_001.jpg'},
#   {'width': 2598,
#    'height': 3358,
#    'id': 248,
#    'file_name': 'images\\2027C46BD015_001.jpg'},
#   {'width': 2606,
#    'height': 3346,
#    'id': 249,
#    'file_name': 'images\\2027C43FD007_001.jpg'},
#   {'width': 2594,
#    'height': 3368,
#    'id': 250,
#    'file_name': 'images\\2027C48FD026_001.jpg'},
#   {'width': 2606,
#    'height': 3351,
#    'id': 251,
#    'file_name': 'images\\2027C43GD021_001.jpg'},
#   {'width': 2607,
#    'height': 3363,
#    'id': 252,
#    'file_name': 'images\\2027C46BD006_001.jpg'},
#   {'width': 2598,
#    'height': 3363,
#    'id': 253,
#    'file_name': 'images\\2027C469D028_001.jpg'},
#   {'width': 2595,
#    'height': 3353,
#    'id': 254,
#    'file_name': 'images\\2027C44TD002_001.jpg'},
#   {'width': 2601,
#    'height': 3358,
#    'id': 255,
#    'file_name': 'images\\2027C43GD037_001.jpg'},
#   {'width': 2606,
#    'height': 3374,
#    'id': 256,
#    'file_name': 'images\\2027C46BD004_001.jpg'},
#   {'width': 2596,
#    'height': 3361,
#    'id': 257,
#    'file_name': 'images\\2027C467D008_001.jpg'},
#   {'width': 2598,
#    'height': 3359,
#    'id': 258,
#    'file_name': 'images\\2027C46DD010_001.jpg'},
#   {'width': 2607,
#    'height': 3346,
#    'id': 259,
#    'file_name': 'images\\2027C43FD008_001.jpg'},
#   {'width': 2605,
#    'height': 3364,
#    'id': 260,
#    'file_name': 'images\\2027C43OD018_001.jpg'},
#   {'width': 2597,
#    'height': 3358,
#    'id': 261,
#    'file_name': 'images\\2027C45AD046_001.jpg'},
#   {'width': 2605,
#    'height': 3375,
#    'id': 262,
#    'file_name': 'images\\2027C44XD033_001.jpg'},
#   {'width': 2599,
#    'height': 3347,
#    'id': 263,
#    'file_name': 'images\\2027C43GD014_001.jpg'},
#   {'width': 2598,
#    'height': 3363,
#    'id': 264,
#    'file_name': 'images\\2027C45BD023_001.jpg'},
#   {'width': 2653,
#    'height': 3387,
#    'id': 265,
#    'file_name': 'images\\2027C43KD013_001.jpg'},
#   {'width': 2600,
#    'height': 3365,
#    'id': 266,
#    'file_name': 'images\\2027C44WD011_001.jpg'},
#   {'width': 2600,
#    'height': 3358,
#    'id': 267,
#    'file_name': 'images\\2027C44WD016_001.jpg'},
#   {'width': 2594,
#    'height': 3361,
#    'id': 268,
#    'file_name': 'images\\2027C45KD001_001.jpg'},
#   {'width': 2610,
#    'height': 3364,
#    'id': 269,
#    'file_name': 'images\\2027C467D010_001.jpg'},
#   {'width': 2606,
#    'height': 3370,
#    'id': 270,
#    'file_name': 'images\\2027C443D012_001.jpg'},
#   {'width': 2581,
#    'height': 3321,
#    'id': 271,
#    'file_name': 'images\\2027C46MD003_001.jpg'},
#   {'width': 2601,
#    'height': 3360,
#    'id': 272,
#    'file_name': 'images\\2027C469D003_001.jpg'},
#   {'width': 2599,
#    'height': 3354,
#    'id': 273,
#    'file_name': 'images\\2027C43GD025_001.jpg'},
#   {'width': 2607,
#    'height': 3367,
#    'id': 274,
#    'file_name': 'images\\2027C447D012_001.jpg'},
#   {'width': 2577,
#    'height': 3330,
#    'id': 275,
#    'file_name': 'images\\2027C46OD001_001.jpg'},
#   {'width': 2596,
#    'height': 3355,
#    'id': 276,
#    'file_name': 'images\\2027C48FD015_001.jpg'},
#   {'width': 2597,
#    'height': 3359,
#    'id': 277,
#    'file_name': 'images\\2027C46DD005_001.jpg'},
#   {'width': 2593,
#    'height': 3358,
#    'id': 278,
#    'file_name': 'images\\2027C46BD016_001.jpg'},
#   {'width': 2596,
#    'height': 3366,
#    'id': 279,
#    'file_name': 'images\\2027C43OD011_001.jpg'},
#   {'width': 2595,
#    'height': 3328,
#    'id': 280,
#    'file_name': 'images\\2027C46QD002_001.jpg'},
#   {'width': 2593,
#    'height': 3358,
#    'id': 281,
#    'file_name': 'images\\2027C46DD013_001.jpg'},
#   {'width': 2585,
#    'height': 3348,
#    'id': 282,
#    'file_name': 'images\\2027C44YD043_001.jpg'},
#   {'width': 2604,
#    'height': 3361,
#    'id': 283,
#    'file_name': 'images\\2027C43OD002_001.jpg'},
#   {'width': 2607,
#    'height': 3354,
#    'id': 284,
#    'file_name': 'images\\2027C469D006_001.jpg'},
#   {'width': 2600,
#    'height': 3357,
#    'id': 285,
#    'file_name': 'images\\2027C482D037_001.jpg'},
#   {'width': 2596,
#    'height': 3359,
#    'id': 286,
#    'file_name': 'images\\2027C46BD010_001.jpg'},
#   {'width': 2614,
#    'height': 3360,
#    'id': 287,
#    'file_name': 'images\\2027C43BD005_001.jpg'},
#   {'width': 2604,
#    'height': 3362,
#    'id': 288,
#    'file_name': 'images\\2027C43SD011_001.jpg'},
#   {'width': 2614,
#    'height': 3351,
#    'id': 289,
#    'file_name': 'images\\2027C48FD049_001.jpg'},
#   {'width': 2608,
#    'height': 3357,
#    'id': 290,
#    'file_name': 'images\\2027C43ND006_001.jpg'},
#   {'width': 2597,
#    'height': 3351,
#    'id': 291,
#    'file_name': 'images\\2027C488D018_001.jpg'},
#   {'width': 2603,
#    'height': 3358,
#    'id': 292,
#    'file_name': 'images\\2027C43GD035_001.jpg'},
#   {'width': 2610,
#    'height': 3376,
#    'id': 293,
#    'file_name': 'images\\2027C45KD004_001.jpg'},
#   {'width': 2619,
#    'height': 3372,
#    'id': 294,
#    'file_name': 'images\\2027C44WD009_001.jpg'},
#   {'width': 2598,
#    'height': 3329,
#    'id': 295,
#    'file_name': 'images\\2027C46QD003_001.jpg'},
#   {'width': 2603,
#    'height': 3352,
#    'id': 296,
#    'file_name': 'images\\2027C43AD003_001.jpg'},
#   {'width': 2597,
#    'height': 3356,
#    'id': 297,
#    'file_name': 'images\\2027C43UD018_001.jpg'},
#   {'width': 2600,
#    'height': 3348,
#    'id': 298,
#    'file_name': 'images\\2027C46DD015_001.jpg'},
#   {'width': 2598,
#    'height': 3368,
#    'id': 299,
#    'file_name': 'images\\2027C43RD006_001.jpg'},
#   {'width': 2597,
#    'height': 3337,
#    'id': 300,
#    'file_name': 'images\\2027C46QD001_001.jpg'},
#   {'width': 2588,
#    'height': 3359,
#    'id': 301,
#    'file_name': 'images\\2027C47SD030_001.jpg'},
#   {'width': 2599,
#    'height': 3357,
#    'id': 302,
#    'file_name': 'images\\2027C43QD019_001.jpg'},
#   {'width': 2597,
#    'height': 3359,
#    'id': 303,
#    'file_name': 'images\\2027C44XD032_001.jpg'},
#   {'width': 2604,
#    'height': 3370,
#    'id': 304,
#    'file_name': 'images\\2027C48FD033_001.jpg'},
#   {'width': 2593,
#    'height': 3362,
#    'id': 305,
#    'file_name': 'images\\2027C45CD012_001.jpg'},
#   {'width': 2606,
#    'height': 3357,
#    'id': 306,
#    'file_name': 'images\\2027C43QD010_001.jpg'},
#   {'width': 2604,
#    'height': 3362,
#    'id': 307,
#    'file_name': 'images\\2027C48FD037_001.jpg'},
#   {'width': 2607,
#    'height': 3351,
#    'id': 308,
#    'file_name': 'images\\2027C43ED008_001.jpg'},
#   {'width': 2562,
#    'height': 3273,
#    'id': 309,
#    'file_name': 'images\\2027C48HD002_001.jpg'},
#   {'width': 2609,
#    'height': 3290,
#    'id': 310,
#    'file_name': 'images\\2027C43LD006_001.jpg'},
#   {'width': 2592,
#    'height': 3326,
#    'id': 311,
#    'file_name': 'images\\2027C46BD021_001.jpg'},
#   {'width': 2614,
#    'height': 3359,
#    'id': 312,
#    'file_name': 'images\\2027C43LD003_001.jpg'},
#   {'width': 2602,
#    'height': 3358,
#    'id': 313,
#    'file_name': 'images\\2027C44WD012_001.jpg'},
#   {'width': 2589,
#    'height': 3341,
#    'id': 314,
#    'file_name': 'images\\2027C46DD016_001.jpg'},
#   {'width': 2585,
#    'height': 3330,
#    'id': 315,
#    'file_name': 'images\\2027C46DD022_001.jpg'},
#   {'width': 2595,
#    'height': 3361,
#    'id': 316,
#    'file_name': 'images\\2027C48FD034_001.jpg'},
#   {'width': 2598,
#    'height': 3345,
#    'id': 317,
#    'file_name': 'images\\2027C46DD017_001.jpg'},
#   {'width': 2607,
#    'height': 3346,
#    'id': 318,
#    'file_name': 'images\\2027C43GD030_001.jpg'},
#   {'width': 2595,
#    'height': 3355,
#    'id': 319,
#    'file_name': 'images\\2027C48FD012_001.jpg'},
#   {'width': 2600,
#    'height': 3365,
#    'id': 320,
#    'file_name': 'images\\2027C48FD021_001.jpg'},
#   {'width': 2597,
#    'height': 3358,
#    'id': 321,
#    'file_name': 'images\\2027C44XD001_001.jpg'},
#   {'width': 2601,
#    'height': 3360,
#    'id': 322,
#    'file_name': 'images\\2027C44XD043_001.jpg'},
#   {'width': 2600,
#    'height': 3366,
#    'id': 323,
#    'file_name': 'images\\2027C46BD009_001.jpg'},
#   {'width': 2607,
#    'height': 3367,
#    'id': 324,
#    'file_name': 'images\\2027C48HD012_001.jpg'},
#   {'width': 2596,
#    'height': 3356,
#    'id': 325,
#    'file_name': 'images\\2027C465D004_001.jpg'},
#   {'width': 2612,
#    'height': 3358,
#    'id': 326,
#    'file_name': 'images\\2027C44YD041_001.jpg'},
#   {'width': 2607,
#    'height': 3361,
#    'id': 327,
#    'file_name': 'images\\2027C43OD014_001.jpg'},
#   {'width': 2591,
#    'height': 3364,
#    'id': 328,
#    'file_name': 'images\\2027C469D030_001.jpg'},
#   {'width': 2594,
#    'height': 3357,
#    'id': 329,
#    'file_name': 'images\\2027C469D025_001.jpg'},
#   {'width': 2591,
#    'height': 3336,
#    'id': 330,
#    'file_name': 'images\\2027C467D029_001.jpg'},
#   {'width': 2591,
#    'height': 3363,
#    'id': 331,
#    'file_name': 'images\\2027C467D025_001.jpg'},
#   {'width': 2598,
#    'height': 3360,
#    'id': 332,
#    'file_name': 'images\\2027C469D017_001.jpg'},
#   {'width': 2598,
#    'height': 3364,
#    'id': 333,
#    'file_name': 'images\\2027C467D016_001.jpg'},
#   {'width': 2598,
#    'height': 3362,
#    'id': 334,
#    'file_name': 'images\\2027C46BD005_001.jpg'},
#   {'width': 2595,
#    'height': 3360,
#    'id': 336,
#    'file_name': 'images\\2027C467D022_001.jpg'},
#   {'width': 2614,
#    'height': 3349,
#    'id': 337,
#    'file_name': 'images\\2027C43BD006_001.jpg'},
#   {'width': 2601,
#    'height': 3362,
#    'id': 338,
#    'file_name': 'images\\2027C45GD001_001.jpg'},
#   {'width': 2591,
#    'height': 3325,
#    'id': 339,
#    'file_name': 'images\\2027C46HD002_001.jpg'},
#   {'width': 2599,
#    'height': 3361,
#    'id': 340,
#    'file_name': 'images\\2027C44XD042_001.jpg'},
#   {'width': 2597,
#    'height': 3363,
#    'id': 341,
#    'file_name': 'images\\2027C45DD044_001.jpg'},
#   {'width': 2606,
#    'height': 3349,
#    'id': 342,
#    'file_name': 'images\\2027C450D027_001.jpg'},
#   {'width': 2596,
#    'height': 3359,
#    'id': 343,
#    'file_name': 'images\\2027C45AD037_001.jpg'},
#   {'width': 2598,
#    'height': 3363,
#    'id': 344,
#    'file_name': 'images\\2027C45AD038_001.jpg'},
#   {'width': 2597,
#    'height': 3350,
#    'id': 345,
#    'file_name': 'images\\2027C43LD011_001.jpg'},
#   {'width': 2592,
#    'height': 3356,
#    'id': 346,
#    'file_name': 'images\\2027C465D009_001.jpg'},
#   {'width': 2594,
#    'height': 3358,
#    'id': 347,
#    'file_name': 'images\\2027C45AD033_001.jpg'},
#   {'width': 2597,
#    'height': 3361,
#    'id': 348,
#    'file_name': 'images\\2027C467D001_001.jpg'},
#   {'width': 2603,
#    'height': 3356,
#    'id': 349,
#    'file_name': 'images\\2027C469D010_001.jpg'},
#   {'width': 2588,
#    'height': 3333,
#    'id': 350,
#    'file_name': 'images\\2027C467D028_001.jpg'},
#   {'width': 2606,
#    'height': 3369,
#    'id': 351,
#    'file_name': 'images\\2027C43OD003_001.jpg'},
#   {'width': 2597,
#    'height': 3359,
#    'id': 352,
#    'file_name': 'images\\2027C45AD041_001.jpg'},
#   {'width': 2581,
#    'height': 3330,
#    'id': 353,
#    'file_name': 'images\\2027C46MD001_001.jpg'},
#   {'width': 2593,
#    'height': 3363,
#    'id': 354,
#    'file_name': 'images\\2027C469D021_001.jpg'},
#   {'width': 2594,
#    'height': 3356,
#    'id': 355,
#    'file_name': 'images\\2027C43RD002_001.jpg'},
#   {'width': 2594,
#    'height': 3326,
#    'id': 356,
#    'file_name': 'images\\2027C46QD004_001.jpg'},
#   {'width': 2609,
#    'height': 3348,
#    'id': 357,
#    'file_name': 'images\\2027C48GD009_001.jpg'},
#   {'width': 2598,
#    'height': 3353,
#    'id': 358,
#    'file_name': 'images\\2027C43GD006_001.jpg'},
#   {'width': 2593,
#    'height': 3358,
#    'id': 359,
#    'file_name': 'images\\2027C469D027_001.jpg'},
#   {'width': 2600,
#    'height': 3358,
#    'id': 360,
#    'file_name': 'images\\2027C43QD016_001.jpg'},
#   {'width': 2597,
#    'height': 3369,
#    'id': 361,
#    'file_name': 'images\\2027C43SD005_001.jpg'},
#   {'width': 2609,
#    'height': 3350,
#    'id': 362,
#    'file_name': 'images\\2027C48HD043_001.jpg'},
#   {'width': 2599,
#    'height': 3353,
#    'id': 363,
#    'file_name': 'images\\2027C44YD032_001.jpg'},
#   {'width': 2602,
#    'height': 3363,
#    'id': 364,
#    'file_name': 'images\\2027C48FD017_001.jpg'},
#   {'width': 2625,
#    'height': 3364,
#    'id': 365,
#    'file_name': 'images\\2027C43AD010_001.jpg'},
#   {'width': 2598,
#    'height': 3364,
#    'id': 366,
#    'file_name': 'images\\2027C469D012_001.jpg'},
#   {'width': 2606,
#    'height': 3357,
#    'id': 367,
#    'file_name': 'images\\2027C44XD041_001.jpg'},
#   {'width': 2605,
#    'height': 3357,
#    'id': 368,
#    'file_name': 'images\\2027C469D007_001.jpg'},
#   {'width': 2600,
#    'height': 3357,
#    'id': 369,
#    'file_name': 'images\\2027C44YD040_001.jpg'},
#   {'width': 2602,
#    'height': 3348,
#    'id': 370,
#    'file_name': 'images\\2027C43LD007_001.jpg'},
#   {'width': 2612,
#    'height': 3351,
#    'id': 372,
#    'file_name': 'images\\2027C43ID023_001.jpg'},
#   {'width': 2600,
#    'height': 3355,
#    'id': 373,
#    'file_name': 'images\\2027C43AD017_001.jpg'},
#   {'width': 2600,
#    'height': 3356,
#    'id': 374,
#    'file_name': 'images\\2027C47SD038_001.jpg'},
#   {'width': 2605,
#    'height': 3368,
#    'id': 375,
#    'file_name': 'images\\2027C467D013_001.jpg'},
#   {'width': 2621,
#    'height': 3367,
#    'id': 376,
#    'file_name': 'images\\2027C44WD013_001.jpg'},
#   {'width': 2595,
#    'height': 3358,
#    'id': 377,
#    'file_name': 'images\\2027C43QD005_001.jpg'},
#   {'width': 2590,
#    'height': 3365,
#    'id': 378,
#    'file_name': 'images\\2027C46BD014_001.jpg'},
#   {'width': 2600,
#    'height': 3366,
#    'id': 379,
#    'file_name': 'images\\2027C43RD017_001.jpg'},
#   {'width': 2598,
#    'height': 3355,
#    'id': 380,
#    'file_name': 'images\\2027C47XD019_001.jpg'},
#   {'width': 2591,
#    'height': 3367,
#    'id': 381,
#    'file_name': 'images\\2027C43UD017_001.jpg'},
#   {'width': 2592,
#    'height': 3356,
#    'id': 382,
#    'file_name': 'images\\2027C469D019_001.jpg'},
#   {'width': 2605,
#    'height': 3367,
#    'id': 383,
#    'file_name': 'images\\2027C48HD004_001.jpg'},
#   {'width': 2600,
#    'height': 3345,
#    'id': 384,
#    'file_name': 'images\\2027C48GD014_001.jpg'},
#   {'width': 2596,
#    'height': 3367,
#    'id': 385,
#    'file_name': 'images\\2027C43QD009_001.jpg'},
#   {'width': 2601,
#    'height': 3362,
#    'id': 386,
#    'file_name': 'images\\2027C469D026_001.jpg'},
#   {'width': 2603,
#    'height': 3368,
#    'id': 387,
#    'file_name': 'images\\2027C464D017_001.jpg'},
#   {'width': 2591,
#    'height': 3349,
#    'id': 388,
#    'file_name': 'images\\2027C464D015_001.jpg'},
#   {'width': 2596,
#    'height': 3362,
#    'id': 389,
#    'file_name': 'images\\2027C467D005_001.jpg'},
#   {'width': 2605,
#    'height': 3355,
#    'id': 390,
#    'file_name': 'images\\2027C43ID006_001.jpg'},
#   {'width': 2596,
#    'height': 3360,
#    'id': 391,
#    'file_name': 'images\\2027C43QD007_001.jpg'},
#   {'width': 2599,
#    'height': 3351,
#    'id': 392,
#    'file_name': 'images\\2027C43LD002_001.jpg'},
#   {'width': 2599,
#    'height': 3362,
#    'id': 393,
#    'file_name': 'images\\2027C45CD011_001.jpg'},
#   {'width': 2598,
#    'height': 3353,
#    'id': 394,
#    'file_name': 'images\\2027C44JD029_001.jpg'},
#   {'width': 2608,
#    'height': 3359,
#    'id': 395,
#    'file_name': 'images\\2027C44XD050_001.jpg'},
#   {'width': 2605,
#    'height': 3350,
#    'id': 396,
#    'file_name': 'images\\2027C43MD012_001.jpg'},
#   {'width': 2603,
#    'height': 3361,
#    'id': 397,
#    'file_name': 'images\\2027C43TD024_001.jpg'},
#   {'width': 2613,
#    'height': 3371,
#    'id': 398,
#    'file_name': 'images\\2027C45KD019_001.jpg'},
#   {'width': 2603,
#    'height': 3344,
#    'id': 399,
#    'file_name': 'images\\2027C43ID020_001.jpg'},
#   {'width': 2608,
#    'height': 3351,
#    'id': 400,
#    'file_name': 'images\\2027C43ND010_001.jpg'},
#   {'width': 2593,
#    'height': 3361,
#    'id': 401,
#    'file_name': 'images\\2027C46BD007_001.jpg'},
#   {'width': 2609,
#    'height': 3355,
#    'id': 402,
#    'file_name': 'images\\2027C43MD006_001.jpg'},
#   {'width': 2599,
#    'height': 3351,
#    'id': 403,
#    'file_name': 'images\\2027C47SD005_001.jpg'},
#   {'width': 2602,
#    'height': 3362,
#    'id': 404,
#    'file_name': 'images\\2027C43TD031_001.jpg'},
#   {'width': 2606,
#    'height': 3353,
#    'id': 405,
#    'file_name': 'images\\2027C43HD011_001.jpg'},
#   {'width': 2612,
#    'height': 3383,
#    'id': 406,
#    'file_name': 'images\\2027C469D002_001.jpg'},
#   {'width': 2603,
#    'height': 3350,
#    'id': 407,
#    'file_name': 'images\\2027C48FD046_001.jpg'},
#   {'width': 2594,
#    'height': 3361,
#    'id': 408,
#    'file_name': 'images\\2027C457D011_001.jpg'},
#   {'width': 2618,
#    'height': 3370,
#    'id': 409,
#    'file_name': 'images\\2027C43AD012_001.jpg'},
#   {'width': 2595,
#    'height': 3357,
#    'id': 410,
#    'file_name': 'images\\2027C45GD008_001.jpg'},
#   {'width': 2610,
#    'height': 3373,
#    'id': 411,
#    'file_name': 'images\\2027C43UD050_001.jpg'},
#   {'width': 2611,
#    'height': 3366,
#    'id': 412,
#    'file_name': 'images\\2027C43MD004_001.jpg'},
#   {'width': 2592,
#    'height': 3362,
#    'id': 413,
#    'file_name': 'images\\2027C43SD012_001.jpg'},
#   {'width': 2622,
#    'height': 3364,
#    'id': 414,
#    'file_name': 'images\\2027C43HD023_001.jpg'},
#   {'width': 2602,
#    'height': 3360,
#    'id': 415,
#    'file_name': 'images\\2027C43SD028_001.jpg'},
#   {'width': 2595,
#    'height': 3354,
#    'id': 416,
#    'file_name': 'images\\2027C43TD014_001.jpg'},
#   {'width': 2603,
#    'height': 3367,
#    'id': 417,
#    'file_name': 'images\\2027C45AD042_001.jpg'},
#   {'width': 2615,
#    'height': 3357,
#    'id': 419,
#    'file_name': 'images\\2027C43HD002_001.jpg'},
#   {'width': 2594,
#    'height': 3352,
#    'id': 420,
#    'file_name': 'images\\2027C43UD006_001.jpg'},
#   {'width': 2599,
#    'height': 3363,
#    'id': 421,
#    'file_name': 'images\\2027C44XD034_001.jpg'}],
#  'annotations': [{'id': 0,
#    'image_id': 0,
#    'category_id': 38,
#    'segmentation': [],
#    'bbox': [1313.1339546530467,
#     2390.4549999999836,
#     265.34453401021005,
#     50.689999999999635],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 13450.31442897745},
#   {'id': 1,
#    'image_id': 0,
#    'category_id': 27,
#    'segmentation': [],
#    'bbox': [1152.7899999999995,
#     1501.0699999999977,
#     169.74906802042523,
#     46.69999999999992],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 7927.281476553844},
#   {'id': 2,
#    'image_id': 0,
#    'category_id': 1,
#    'segmentation': [],
#    'bbox': [847.431287116508,
#     1052.4799999999993,
#     193.9687128834919,
#     50.219999999999985],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 9741.10876100896},
#   {'id': 3,
#    'image_id': 0,
#    'category_id': 9,
#    'segmentation': [],
#    'bbox': [1792.0450000000003,
#     645.7158170665075,
#     123.56298382422563,
#     58.20418293349171],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 7191.882514313305},
#   {'id': 4,
#    'image_id': 0,
#    'category_id': 29,
#    'segmentation': [],
#    'bbox': [2283.921750591773,
#     1498.2049999999927,
#     209.72627208169018,
#     45.849999999999746],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 9615.949574945442},
#   {'id': 5,
#    'image_id': 0,
#    'category_id': 21,
#    'segmentation': [],
#    'bbox': [1726.19, 1244.5349999999999, 62.54, 56.67],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 3544.1418},
#   {'id': 6,
#    'image_id': 0,
#    'category_id': 27,
#    'segmentation': [],
#    'bbox': [1148.6869773265237,
#     1551.389999999996,
#     174.09209069390008,
#     47.559999999999846],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 8279.819833401862},
#   {'id': 7,
#    'image_id': 0,
#    'category_id': 26,
#    'segmentation': [],
#    'bbox': [973.6134886632618,
#     1499.4849999999988,
#     171.77906802042565,
#     45.92999999999996],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 7889.812594178143},
#   {'id': 8,
#    'image_id': 0,
#    'category_id': 27,
#    'segmentation': [],
#    'bbox': [1149.8519773265243,
#     1450.5249999999992,
#     175.73906802042544,
#     47.50999999999995],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 8349.363121650404},
#   {'id': 9,
#    'image_id': 0,
#    'category_id': 13,
#    'segmentation': [],
#    'bbox': [1932.5250000000003, 901.4850000000001, 126.51000000000002, 50.47],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 6384.959700000001},
#   {'id': 10,
#    'image_id': 0,
#    'category_id': 4,
#    'segmentation': [],
#    'bbox': [668.8300000000002, 1051.1250000000005, 157.5025742330165, 51.09],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 8046.8065175648135},
#   {'id': 11,
#    'image_id': 0,
#    'category_id': 37,
#    'segmentation': [],
#    'bbox': [336.505, 759.59, 178.11, 43.24],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 7701.476400000001},
#   {'id': 12,
#    'image_id': 0,
#    'category_id': 26,
#    'segmentation': [],
#    'bbox': [974.3934886632618,
#     1450.0849999999984,
#     167.81604534694915,
#     47.249999999999915],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 7929.308142643333},
#   {'id': 13,
#    'image_id': 0,
#    'category_id': 29,
#    'segmentation': [],
#    'bbox': [2287.494773265247,
#     1547.5599999999927,
#     210.24627208169363,
#     48.6999999999997],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 10238.993450378417},
#   {'id': 14,
#    'image_id': 0,
#    'category_id': 26,
#    'segmentation': [],
#    'bbox': [972.9769773265243,
#     1549.424999999998,
#     170.569068020425,
#     46.98999999999991],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 8015.040506279755},
#   {'id': 15,
#    'image_id': 0,
#    'category_id': 32,
#    'segmentation': [],
#    'bbox': [1471.9599999999978,
#     2000.4949999999947,
#     629.947556683689,
#     94.54999999999973],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 59561.54148444262},
#   {'id': 16,
#    'image_id': 0,
#    'category_id': 29,
#    'segmentation': [],
#    'bbox': [2290.461750591773,
#     1446.099999999991,
#     204.68778341842946,
#     48.85999999999967],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 10001.045097824397},
#   {'id': 17,
#    'image_id': 0,
#    'category_id': 23,
#    'segmentation': [],
#    'bbox': [109.54895465304989,
#     1551.8499999999972,
#     320.4451133673745,
#     45.57999999999989],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 14605.888267284896},
#   {'id': 18,
#    'image_id': 0,
#    'category_id': 12,
#    'segmentation': [],
#    'bbox': [1655.2699999999998, 904.9050000000002, 258.38, 46.72999999999999],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 12074.097399999997},
#   {'id': 19,
#    'image_id': 0,
#    'category_id': 35,
#    'segmentation': [],
#    'bbox': [128.65500000000006, 2598.84, 406.88999999999993, 47.96],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 19514.444399999997},
#   {'id': 20,
#    'image_id': 0,
#    'category_id': 14,
#    'segmentation': [],
#    'bbox': [1334.245, 905.81, 114.43, 48.02],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 5494.928600000001},
#   {'id': 21,
#    'image_id': 0,
#    'category_id': 15,
#    'segmentation': [],
#    'bbox': [1482.8000000000002, 905.8300000000002, 151.82, 46.54],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 7065.702799999999},
#   {'id': 22,
#    'image_id': 0,
#    'category_id': 2,
#    'segmentation': [],
#    'bbox': [1058.33, 1052.735, 142.31383915508923, 49.21000000000001],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 7003.264024821942},
#   {'id': 23,
#    'image_id': 0,
#    'category_id': 23,
#    'segmentation': [],
#    'bbox': [111.14895465304997,
#     1451.614999999998,
#     313.44057935716165,
#     46.42999999999996],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 14553.046099553003},
#   {'id': 24,
#    'image_id': 0,
#    'category_id': 47,
#    'segmentation': [],
#    'bbox': [2388.6119773265227,
#     2644.1499999999887,
#     105.35302267346584,
#     41.74000000000226],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 4397.435166390703},
#   {'id': 25,
#    'image_id': 0,
#    'category_id': 25,
#    'segmentation': [],
#    'bbox': [612.2849999999976,
#     1552.2149999999933,
#     352.8420906939014,
#     46.28999999999976],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 16333.06037822061},
#   {'id': 26,
#    'image_id': 0,
#    'category_id': 23,
#    'segmentation': [],
#    'bbox': [110.09046598978733,
#     1502.1599999999974,
#     313.0636020306374,
#     43.399999999999906],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 13586.960328129635},
#   {'id': 27,
#    'image_id': 0,
#    'category_id': 3,
#    'segmentation': [],
#    'bbox': [520.935, 1051.215, 117.85257423301651, 50.29000000000003],
#    'ignore': 0,
# ...
#    'image_id': 12,
#    'category_id': 31,
#    'segmentation': [],
#    'bbox': [1468.4199999999996, 1905.685, 92.54, 46.01],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 4257.7654},
#   {'id': 952,
#    'image_id': 12,
#    'category_id': 12,
#    'segmentation': [],
#    'bbox': [1643.7908781846209,
#     878.8573512738479,
#     266.5829461784528,
#     47.85764872615082],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 12758.032994590765},
#   {'id': 953,
#    'image_id': 12,
#    'category_id': 16,
#    'segmentation': [],
#    'bbox': [1311.7099999999991,
#     978.4323512738489,
#     305.17999999999984,
#     45.367648726150776],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 13845.299038246687},
#   {'id': 954,
#    'image_id': 12,
#    'category_id': 34,
#    'segmentation': [],
#    'bbox': [127.54499999999986,
#     2344.399702547698,
#     314.3297167199815,
#     46.685297452301455],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 14674.57632316999},
#   {'id': 955,
#    'image_id': 12,
#    'category_id': 32,
#    'segmentation': [],
#    'bbox': [1466.614999999999,
#     1952.1849999999995,
#     629.1129461784536,
#     94.1699999999998],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 59243.566141624855},
#   {'id': 956,
#    'image_id': 12,
#    'category_id': 23,
#    'segmentation': [],
#    'bbox': [115.35735127384892,
#     1415.7699999999988,
#     313.07912181537756,
#     45.119999999999955],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 14126.129976309821},
#   {'id': 957,
#    'image_id': 12,
#    'category_id': 29,
#    'segmentation': [],
#    'bbox': [2279.4623512738485,
#     1414.8649999999993,
#     203.68764872615148,
#     45.06999999999997],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 9180.202328087642},
#   {'id': 958,
#    'image_id': 12,
#    'category_id': 24,
#    'segmentation': [],
#    'bbox': [433.5849999999994,
#     1416.0749999999985,
#     85.11764872615142,
#     44.22999999999993],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 3764.7536031576715},
#   {'id': 959,
#    'image_id': 12,
#    'category_id': 36,
#    'segmentation': [],
#    'bbox': [79.69205382154684,
#     741.9399999999991,
#     204.5667705415283,
#     40.23999999999995],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 8231.76684659109},
#   {'id': 960,
#    'image_id': 12,
#    'category_id': 3,
#    'segmentation': [],
#    'bbox': [522.3849999999999,
#     1025.6399999999996,
#     122.38529745230207,
#     48.49999999999994],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 5935.686926436643},
#   {'id': 961,
#    'image_id': 12,
#    'category_id': 42,
#    'segmentation': [],
#    'bbox': [1976.2858781846203,
#     2431.2399999999952,
#     503.3511898092103,
#     52.18764872615146],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 26268.715079653455},
#   {'id': 962,
#    'image_id': 12,
#    'category_id': 14,
#    'segmentation': [],
#    'bbox': [1328.0200000000002,
#     883.0349999999995,
#     129.0567705415285,
#     45.109999999999985],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 5821.750919128349},
#   {'id': 963,
#    'image_id': 12,
#    'category_id': 45,
#    'segmentation': [],
#    'bbox': [2054.9970538215466,
#     2529.9049999999975,
#     275.8135410830543,
#     56.88382436307656],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 15689.329027926662},
#   {'id': 964,
#    'image_id': 12,
#    'category_id': 55,
#    'segmentation': [],
#    'bbox': [1312.4085269107723,
#     2788.3149999999932,
#     347.6520679938248,
#     50.87764872615074],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 17687.71979430969},
#   {'id': 965,
#    'image_id': 12,
#    'category_id': 43,
#    'segmentation': [],
#    'bbox': [1749.7805807323195,
#     2524.8349999999923,
#     266.72648726151,
#     59.523824363075676],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 15876.580580734262},
#   {'id': 966,
#    'image_id': 12,
#    'category_id': 27,
#    'segmentation': [],
#    'bbox': [1144.7658781846212,
#     1415.8499999999951,
#     172.44677054152908,
#     46.09999999999984],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 7949.796121964462},
#   {'id': 967,
#    'image_id': 12,
#    'category_id': 39,
#    'segmentation': [],
#    'bbox': [1594.1499999999996,
#     2332.5923512738495,
#     322.85999999999996,
#     52.60764872615105],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 16984.905467725126},
#   {'id': 968,
#    'image_id': 12,
#    'category_id': 26,
#    'segmentation': [],
#    'bbox': [970.6973512738488,
#     1416.2399999999982,
#     169.67294617845394,
#     44.79999999999992],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 7601.347988794722},
#   {'id': 969,
#    'image_id': 12,
#    'category_id': 44,
#    'segmentation': [],
#    'bbox': [1310.7108781846205,
#     2532.0649999999955,
#     391.7964872615094,
#     59.42529745230233],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 23282.62279628238},
#   {'id': 970,
#    'image_id': 12,
#    'category_id': 38,
#    'segmentation': [],
#    'bbox': [1315.2623512738483,
#     2335.7349999999983,
#     266.89529745230254,
#     48.02999999999994],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 12818.981136634075},
#   {'id': 971,
#    'image_id': 12,
#    'category_id': 40,
#    'segmentation': [],
#    'bbox': [1973.605580732315,
#     2331.689999999995,
#     507.051784713815,
#     56.12147308922678],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 28456.49309066078},
#   {'id': 972,
#    'image_id': 12,
#    'category_id': 62,
#    'segmentation': [],
#    'bbox': [76.37705382154662,
#     1909.0549999999996,
#     1009.8117847138111,
#     140.0299999999996],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 141403.94421347458},
#   {'id': 973,
#    'image_id': 12,
#    'category_id': 46,
#    'segmentation': [],
#    'bbox': [1700.002917833882,
#     2591.454999999997,
#     386.9097450645503,
#     39.269999999999925],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 15193.94568868486},
#   {'id': 974,
#    'image_id': 12,
#    'category_id': 56,
#    'segmentation': [],
#    'bbox': [1361.7735269107661,
#     2882.6311756369173,
#     427.02773375985896,
#     41.82382436307475],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 17859.932934934186},
#   {'id': 975,
#    'image_id': 12,
#    'category_id': 57,
#    'segmentation': [],
#    'bbox': [2112.5497025476825,
#     2879.0697025476893,
#     371.39980175369936,
#     49.66529745230179],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 18445.681627823396},
#   {'id': 976,
#    'image_id': 12,
#    'category_id': 17,
#    'segmentation': [],
#    'bbox': [1317.475, 1033.495, 272.87, 37.25],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 10164.4075},
#   {'id': 977,
#    'image_id': 12,
#    'category_id': 0,
#    'segmentation': [],
#    'bbox': [578.7299999999993,
#     187.38352691077318,
#     602.3676487261505,
#     65.43294617845314],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 39414.68993873957},
#   {'id': 978,
#    'image_id': 12,
#    'category_id': 8,
#    'segmentation': [],
#    'bbox': [1309.3299999999997,
#     634.0249999999993,
#     284.817053821547,
#     44.88999999999997],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 12785.437546049237},
#   {'id': 979,
#    'image_id': 12,
#    'category_id': 51,
#    'segmentation': [],
#    'bbox': [79.87175636924474,
#     3025.6149999999993,
#     237.1026628984347,
#     35.869999999999955],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 8504.872518166841},
#   {'id': 980,
#    'image_id': 12,
#    'category_id': 22,
#    'segmentation': [],
#    'bbox': [1934.4417563692432,
#     1217.2349999999942,
#     543.3411898092095,
#     57.11147308922675],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 31031.01574005711},
#   {'id': 981,
#    'image_id': 12,
#    'category_id': 20,
#    'segmentation': [],
#    'bbox': [1780.3049999999932,
#     1218.6249999999905,
#     139.0491501599512,
#     55.09764872615077],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 7661.281231182783},
#   {'id': 982,
#    'image_id': 12,
#    'category_id': 0,
#    'segmentation': [],
#    'bbox': [103.56499999999991,
#     249.27617563692434,
#     424.2699999999997,
#     45.89382436307532],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 19471.372862521952},
#   {'id': 983,
#    'image_id': 12,
#    'category_id': 49,
#    'segmentation': [],
#    'bbox': [144.05675636924457,
#     2941.2699999999973,
#     508.9864872615101,
#     39.46147308922689],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 20085.356569850206},
#   {'id': 984,
#    'image_id': 12,
#    'category_id': 52,
#    'segmentation': [],
#    'bbox': [78.0911614646404,
#     830.1549999999896,
#     1195.1054391751384,
#     52.19764872615022],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 62381.69390477536},
#   {'id': 985,
#    'image_id': 12,
#    'category_id': 61,
#    'segmentation': [],
#    'bbox': [83.73970254769773,
#     1024.7149999999947,
#     414.0247308922654,
#     51.117648726150854],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 21163.97075768996},
#   {'id': 986,
#    'image_id': 12,
#    'category_id': 33,
#    'segmentation': [],
#    'bbox': [76.89487244944463,
#     2054.483526910767,
#     2401.8107651376567,
#     91.3729461784504],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 219460.5257737459},
#   {'id': 987,
#    'image_id': 12,
#    'category_id': 0,
#    'segmentation': [],
#    'bbox': [100.78852691077334,
#     198.2049999999996,
#     418.66589235690583,
#     46.58382436307544],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 19503.05839636435},
#   {'id': 988,
#    'image_id': 12,
#    'category_id': 19,
#    'segmentation': [],
#    'bbox': [1328.1199999999985,
#     1222.474999999991,
#     231.73790366160085,
#     48.27764872615078],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 11187.761109509336},
#   {'id': 989,
#    'image_id': 12,
#    'category_id': 28,
#    'segmentation': [],
#    'bbox': [127.00322945847128,
#     485.06117563692334,
#     238.1767705415284,
#     50.45912181537759],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 12018.190678348219},
#   {'id': 990,
#    'image_id': 12,
#    'category_id': 30,
#    'segmentation': [],
#    'bbox': [2259.8432011139025,
#     2003.9138243630732,
#     222.934447612242,
#     45.0261756369241],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 10037.885593709463},
#   {'id': 991,
#    'image_id': 12,
#    'category_id': 9,
#    'segmentation': [],
#    'bbox': [1784.9497025476971,
#     633.2049999999997,
#     118.26529745230151,
#     53.90999999999995],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 6375.682185653568},
#   {'id': 992,
#    'image_id': 12,
#    'category_id': 48,
#    'segmentation': [],
#    'bbox': [165.45499999999925,
#     2835.254999999997,
#     314.4699999999989,
#     96.94943343996634],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 30487.688333866106},
#   {'id': 993,
#    'image_id': 12,
#    'category_id': 50,
#    'segmentation': [],
#    'bbox': [161.40999999999994,
#     2784.005,
#     378.9599999999998,
#     45.31147308922653],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 17171.235841893278},
#   {'id': 994,
#    'image_id': 12,
#    'category_id': 54,
#    'segmentation': [],
#    'bbox': [875.299702547698,
#     3022.7249999999976,
#     220.0420679938308,
#     46.269999999999875],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 10181.346486074524},
#   {'id': 995,
#    'image_id': 12,
#    'category_id': 15,
#    'segmentation': [],
#    'bbox': [1470.5547025476976,
#     881.6961756369224,
#     158.65529745230134,
#     46.03382436307536],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 7303.510097190718},
#   {'id': 996,
#    'image_id': 12,
#    'category_id': 18,
#    'segmentation': [],
#    'bbox': [1305.3541076430922,
#     1080.7149999999958,
#     456.3903116245856,
#     53.49294617845375],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 24413.662376101693},
#   {'id': 997,
#    'image_id': 12,
#    'category_id': 6,
#    'segmentation': [],
#    'bbox': [1318.1085269107734,
#     488.1799999999997,
#     464.03354108305723,
#     43.07999999999995],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 19990.564949858082},
#   {'id': 998,
#    'image_id': 12,
#    'category_id': 7,
#    'segmentation': [],
#    'bbox': [1307.9944050953952,
#     388.1049999999993,
#     246.580594904602,
#     38.6299999999999],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 9525.408381164752},
#   {'id': 999,
#    'image_id': 12,
#    'category_id': 60,
#    'segmentation': [],
#    'bbox': [730.7197025476963,
#     929.4899999999964,
#     546.0388385353577,
#     48.27382436307568],
#    'ignore': 0,
#    'iscrowd': 0,
#    'area': 26359.3829868737},
#   ...],
#  'categories': [{'id': 0,
#    'name': '1.  Type of Transaction (Mark all applicable boxes)'},
#   {'id': 1,
#    'name': '10. Patient’s Relationship to Person named in #5 Dependent'},
#   {'id': 2, 'name': '10. Patient’s Relationship to Person named in #5 Other'},
#   {'id': 3, 'name': '10. Patient’s Relationship to Person named in #5 Self'},
#   {'id': 4, 'name': '10. Patient’s Relationship to Person named in #5 Spouse'},
#   {'id': 5, 'name': '12. Policyholder/Subscriber Address'},
#   {'id': 6, 'name': '12. Policyholder/Subscriber City'},
#   {'id': 7,
#    'name': '12. Policyholder/Subscriber Name (Last, First, Middle Initial, Suffix)'},
#   {'id': 8, 'name': '13. Date of Birth (MM/DD/CCYY)'},
#   {'id': 9, 'name': '14. Policyholder_Gender F'},
#   {'id': 10, 'name': '14. Policyholder_Gender M'},
#   {'id': 11, 'name': '15. Policyholder/Subscriber ID (SSN or ID#)'},
#   {'id': 12,
#    'name': '18. Relationship to Policyholder/Subscriber in #12 Above Dependent Child'},
#   {'id': 13,
#    'name': '18. Relationship to Policyholder/Subscriber in #12 Above Other'},
#   {'id': 14,
#    'name': '18. Relationship to Policyholder/Subscriber in #12 Above Self'},
#   {'id': 15,
#    'name': '18. Relationship to Policyholder/Subscriber in #12 Above Spouse'},
#   {'id': 16, 'name': '20. Name (Last, First, Middle Initial, Suffix)'},
#   {'id': 17, 'name': '20. Patient_Address'},
#   {'id': 18, 'name': '20. Patient_City'},
#   {'id': 19, 'name': '21. Date of Birth (MM/DD/CCYY)'},
#   {'id': 20, 'name': '22. Patient_Gender F'},
#   {'id': 21, 'name': '22. Patient_Gender M'},
#   {'id': 22, 'name': '23. Patient ID/Account # (Assigned by Dentist)'},
#   {'id': 23, 'name': '24. Procedure Date'},
#   {'id': 24, 'name': '25. Area of Oral Cavity'},
#   {'id': 25, 'name': '27. Tooth Number(s) or Letter(s)'},
#   {'id': 26, 'name': '28. Tooth Surface'},
#   {'id': 27, 'name': '29. Procedure Code'},
#   {'id': 28, 'name': '3. Company/Plan Name, Address, City, State, Zip Code'},
#   {'id': 29, 'name': '31. Fee'},
#   {'id': 30, 'name': '33. Total Fee'},
#   {'id': 31, 'name': '34. Diagnosis Code List Qualifier'},
#   {'id': 32, 'name': '34a. Diagnosis Code(s) (Primary diagnosis in “A”)'},
#   {'id': 33, 'name': '35. Remarks'},
#   {'id': 34, 'name': '36. Patient/Guardian Signature'},
#   {'id': 35, 'name': '37. Subscriber Signature'},
#   {'id': 36, 'name': '4. Dental?'},
#   {'id': 37, 'name': '4. Medical?'},
#   {'id': 38, 'name': '40. Is Treatment for Orthodontics? No'},
#   {'id': 39, 'name': '40. Is Treatment for Orthodontics? Yes'},
#   {'id': 40, 'name': '41. Date Appliance Placed (MM/DD/CCYY)'},
#   {'id': 41, 'name': '43. Replacement of Prosthesis Yes'},
#   {'id': 42, 'name': '44. Date of Prior Placement (MM/DD/CCYY)'},
#   {'id': 43, 'name': '45. Treatment Resulting from Auto accident'},
#   {'id': 44,
#    'name': '45. Treatment Resulting from Occupational illness/injury'},
#   {'id': 45, 'name': '45. Treatment Resulting from Other accident'},
#   {'id': 46, 'name': '46. Date of Accident (MM/DD/CCYY)'},
#   {'id': 47, 'name': '47. Auto Accident State'},
#   {'id': 48, 'name': '48. DEN_Address'},
#   {'id': 49, 'name': '48. DEN_City'},
#   {'id': 50, 'name': '48. DEN_Name'},
#   {'id': 51, 'name': '49. NPI / Provider ID'},
#   {'id': 52,
#    'name': '5.  Name of Policyholder/Subscriber in # 4 (Last, First, Middle Initial, Suffix)'},
#   {'id': 53, 'name': '50. License Number'},
#   {'id': 54, 'name': '51. SSN or TIN'},
#   {'id': 55, 'name': '53. Signed (Treating Dentist)'},
#   {'id': 56, 'name': '54. NPI / Provider ID'},
#   {'id': 57, 'name': '55. License Number'},
#   {'id': 58, 'name': '56. Billing_Prov_Address'},
#   {'id': 59, 'name': '56. Billing_Prov_City'},
#   {'id': 60, 'name': '8. Policyholder/Subscriber ID (SSN or ID#)'},
#   {'id': 61, 'name': '9. Plan/Group Number'},
#   {'id': 62,
#    'name': 'Missing Teeth Information (Place an “X” on each missing tooth.)'},
#   {'id': 63, 'name': 'not available_1'},
#   {'id': 64, 'name': 'not available_2'},
#   {'id': 65, 'name': 'not available_3'},
#   {'id': 66, 'name': 'not available_4'},
#   {'id': 67, 'name': 'not available_5'},
#   {'id': 68, 'name': 'not available_6'},
#   {'id': 69, 'name': 'not available_7'},
#   {'id': 70, 'name': 'not available_8'}]}
